# %% [markdown]
# ## 0) Import Libraries and General Script

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
#import cobra
#from cobra.io import load_model
import pandas as pd
from tqdm import tqdm

# Parameters (Feeding point)
x_feed, y_feed, z_feed = 1.15, 10.24, 0.15     #m

# Monod Kinetics (Modeling of Overflow Metabolism in Batch and Fed-Batch Cultures of Escherichia coli)
# (Lin et.al. 2000)
q_S_max = 1.5     # gS/gX/h
K_S = 0.03         # g/L

# Define seaborn theme
sns.set_theme()
sns.set_context('paper')
# Set the Seaborn color palette
sns.set_palette("colorblind")

# Define scientific formatter in matplotlib
formatter = ticker.ScalarFormatter(useMathText=True)
formatter.set_scientific(True)
formatter.set_powerlimits((-1,1))
formatter.format = '%.1e'

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import pandas as pd

# %% [markdown]
# # dFBA - CFD Lifeline
# ## 1) Introduction
# This jupyter notebook shows how it is possible to combine data coming from CFD simulations with metabolic modeling, specifically dFBA (Dynamic Flux Balance Analysis).
#
# ### 1.1) Cell-Lifelines
# First we have to solve the **general micro-balances** for momentum and mass using Computational Fluid Dynamics (Fluent):
#
# $$
# \begin{aligned}
# &\text{Continuity Equation:}\quad\nabla\cdot\rho U + \frac{\partial \rho}{\partial t} = 0 \\
# &\text{Navier-Stokes:}\quad\frac{\partial}{\partial t}\left(\rho U\right)+\nabla\cdot\left(\rho U \otimes U\right) = - \nabla P + \mu \nabla^2+\frac{1}{3}\mu\nabla\left(\nabla\cdot U\right) + \rho g \\
# &\text{Mass Balance:}\quad\frac{\partial C_i}{\partial t} + \left(U \cdot \nabla\right)C_i = \mathcal{D}\nabla^2 C_i + r_i
# \end{aligned}
# $$
#
# **Eulerian Specification of Fluid Flow:**
#
# Field is represented as function of position $x$ and time $t$. **Flow velocity** is represented by the function:
# $$
# u\left(x,t\right)
# $$
#
# **Lagrangian Specification of Fluid Flow:**
#
# Individual **fluid parcels** are followed through time. The fluid parcels (**cells** in our case) are labeled by some (time-independent) vector field $x_0$ (position of the center of mass of parcels at time $t_0$). In the Lagrangian description, the flow is described by a function:
# $$
# X(x_0,t)
# $$
# The two specifications are related as follows:
# $$
# u\left(X\left(x_0,t\right),t\right) = \frac{\partial X}{\partial t}\left(x_0, t\right)
# $$
# Because both sides describe the velocity of the particle labeled $x_0$ at time $t$.
#
# The **important assumptions** to track **cell lifelines** are:
# * Parcels have same density as the broth.
# * Parcels have same velocity as fluid flows.
# * No boundary layer around the cell.
#
# Load data from the lifelines and plot environment seen by the cell

# %% [markdown]
# # Training on Multiple Lifeline

# %%
import os
import pandas as pd
import numpy as np

folder_path = 'dFBA_Data_Frames_Lifelines - Small'
file_names = sorted(os.listdir(folder_path))

expected_timepoints = 376 # reduced timepoints by 10 for faster runs, just temporary 

for file_name in file_names:
    file_path = os.path.join(folder_path, file_name)
    lifeline_df = pd.read_csv(file_path, sep="\t", index_col=0)

    # Select every 10th row and ensure there are exactly 376 timepoints
    reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
    reduced_df.to_csv(file_path, sep="\t")

data_list = []
filtered_reactions = None

for file_name in file_names:
    file_path = os.path.join(folder_path, file_name)
    lifeline_df = pd.read_csv(file_path, sep="\t", index_col=0)

    if filtered_reactions is None:
        non_constant_fluxes_df = lifeline_df.loc[:, (lifeline_df != lifeline_df.iloc[0]).any()]
        unique_reactions_fluxes_df = non_constant_fluxes_df.loc[:, ~non_constant_fluxes_df.columns.duplicated()]
        filtered_reactions = unique_reactions_fluxes_df.columns

    filtered_lifeline_df = lifeline_df[filtered_reactions]

    if filtered_lifeline_df.shape != (expected_timepoints, len(filtered_reactions)):
        print(f"Shape mismatch for file: {file_name}. Expected ({expected_timepoints}, {len(filtered_reactions)}) but got {filtered_lifeline_df.shape}")

    data_list.append(filtered_lifeline_df.to_numpy())

data_3d = np.stack(data_list, axis=1)
print("Shape of the Big Matrix:", data_3d.shape)
# Out:
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\3474851630.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\3474851630.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\3474851630.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\3474851630.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\3474851630.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\3474851630.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\3474851630.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\3474851630.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\3474851630.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\3474851630.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\3474851630.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\3474851630.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\3474851630.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\3474851630.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# Shape mismatch for file: lifeline_0_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_106_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_120_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_197_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_263_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_397_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_424_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_581_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_658_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_669_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_801_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_84_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_8_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_905_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape of the Big Matrix: (38, 14, 48)

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# Assuming data_3d is original data with shape (n_timesteps, n_samples, n_features)
# Example: n_timesteps = 376, n_samples = 14, n_features = 48

n_timesteps, n_samples, n_features = data_3d.shape

# Initialize a StandardScaler for each feature for each sample
scalers = [[StandardScaler() for _ in range(n_features)] for _ in range(n_samples)]

# Normalized data will have the same shape as data_3d initially
normalized_data = np.empty_like(data_3d, dtype=float)

# Apply the scalers to each feature for each sample across all timesteps
for sample_index in range(n_samples):
    for feature_index in range(n_features):
        # Extract the feature data for the current sample
        feature_data = data_3d[:, sample_index, feature_index].reshape(-1, 1)
        
        # Fit and transform the data using the corresponding scaler
        normalized_feature_data = scalers[sample_index][feature_index].fit_transform(feature_data)
        
        # Assign the normalized data back to its position in the normalized_data array
        normalized_data[:, sample_index, feature_index] = normalized_feature_data.flatten()

# Transpose normalized_data to have the shape (n_samples, n_timesteps, n_features)
normalized_data = np.transpose(normalized_data, (1, 0, 2))

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, RepeatVector, TimeDistributed
from tensorflow.keras.initializers import glorot_uniform, he_normal
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# Assuming five_lifeline is a 3D array with the shape (1, 376, 48)
train_data = normalized_data
val_data = train_data  # Using the same data for validation as a placeholder

# Define the input layer with the shape (timesteps, features)
input_shape = (train_data.shape[1], train_data.shape[2])
inputs = Input(shape=input_shape)

# Encoder layers with glorot_uniform initializer
encoded = LSTM(300, activation='tanh', return_sequences=True,
               kernel_initializer=glorot_uniform(seed=0))(inputs)
encoded = LSTM(200, activation='tanh', return_sequences=True,
               kernel_initializer=glorot_uniform(seed=0))(encoded)
encoded = LSTM(150, activation='tanh', return_sequences=False,
               kernel_initializer=glorot_uniform(seed=0))(encoded)
# Latent space with he_normal initializer
latent_space = Dense(100, activation='tanh',
                     kernel_initializer=he_normal(seed=0))(encoded)

# Decoder layers, repeat the latent space at each timestep
decoded = RepeatVector(input_shape[0])(latent_space)
decoded = LSTM(150, activation='tanh', return_sequences=True,
               kernel_initializer=glorot_uniform(seed=0))(decoded)
decoded = LSTM(200, activation='tanh', return_sequences=True,
               kernel_initializer=glorot_uniform(seed=0))(decoded)
decoded = LSTM(300, activation='tanh', return_sequences=True,
               kernel_initializer=glorot_uniform(seed=0))(decoded)

# Output layer, reconstruct the original input
outputs = TimeDistributed(Dense(input_shape[1]))(decoded)

# Create the autoencoder model
autoencoder = Model(inputs, outputs)
autoencoder.compile(optimizer='adam', loss='mse')

# Summary of the model
autoencoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 38, 48)]          0
#
#  lstm_6 (LSTM)               (None, 38, 300)           418800
#
#  lstm_7 (LSTM)               (None, 38, 200)           400800
#
#  lstm_8 (LSTM)               (None, 150)               210600
#
#  dense_2 (Dense)             (None, 100)               15100
#
#  repeat_vector_1 (RepeatVec  (None, 38, 100)           0
#  tor)
#
#  lstm_9 (LSTM)               (None, 38, 150)           150600
#
#  lstm_10 (LSTM)              (None, 38, 200)           280800
#
#  lstm_11 (LSTM)              (None, 38, 300)           601200
#
#  time_distributed_1 (TimeDi  (None, 38, 48)            14448
#  stributed)
#
# =================================================================
# Total params: 2092348 (7.98 MB)
# Trainable params: 2092348 (7.98 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Callbacks
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=20, min_lr=0.00001)
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Fit the model
history = autoencoder.fit(
    train_data,
    train_data,
    epochs = 500,
    batch_size=32,  # Adjust the batch size if necessary
    validation_data=(val_data, val_data),
    callbacks=[reduce_lr, early_stop]
)

# Predict on the validation set
val_predictions = autoencoder.predict(val_data)

# Compute mean squared error on the validation set
mean_squared_error = np.mean(np.square(val_data - val_predictions))

# Compute root mean squared error (RMSE)
reconstruction_loss = np.sqrt(mean_squared_error)
print(f"Validation RMSE: {reconstruction_loss}")
# Out:
# Epoch 1/500
# 1/1 [==============================] - 12s 12s/step - loss: 0.9927 - val_loss: 0.9903 - lr: 0.0010
# Epoch 2/500
# 1/1 [==============================] - 0s 364ms/step - loss: 0.9903 - val_loss: 0.9857 - lr: 0.0010
# Epoch 3/500
# 1/1 [==============================] - 0s 300ms/step - loss: 0.9857 - val_loss: 0.9808 - lr: 0.0010
# Epoch 4/500
# 1/1 [==============================] - 0s 302ms/step - loss: 0.9808 - val_loss: 0.9714 - lr: 0.0010
# Epoch 5/500
# 1/1 [==============================] - 0s 352ms/step - loss: 0.9714 - val_loss: 0.9561 - lr: 0.0010
# Epoch 6/500
# 1/1 [==============================] - 0s 300ms/step - loss: 0.9561 - val_loss: 0.9492 - lr: 0.0010
# Epoch 7/500
# 1/1 [==============================] - 0s 298ms/step - loss: 0.9492 - val_loss: 0.9857 - lr: 0.0010
# Epoch 8/500
# 1/1 [==============================] - 0s 334ms/step - loss: 0.9857 - val_loss: 0.9788 - lr: 0.0010
# Epoch 9/500
# 1/1 [==============================] - 0s 278ms/step - loss: 0.9788 - val_loss: 0.9701 - lr: 0.0010
# Epoch 10/500
# 1/1 [==============================] - 0s 285ms/step - loss: 0.9701 - val_loss: 0.9493 - lr: 0.0010
# Epoch 11/500
# 1/1 [==============================] - 0s 298ms/step - loss: 0.9493 - val_loss: 0.9481 - lr: 0.0010
# Epoch 12/500
# 1/1 [==============================] - 0s 278ms/step - loss: 0.9481 - val_loss: 0.9507 - lr: 0.0010
# Epoch 13/500
# 1/1 [==============================] - 0s 283ms/step - loss: 0.9507 - val_loss: 0.9449 - lr: 0.0010
# Epoch 14/500
# 1/1 [==============================] - 0s 283ms/step - loss: 0.9449 - val_loss: 0.9343 - lr: 0.0010
# Epoch 15/500
# 1/1 [==============================] - 0s 305ms/step - loss: 0.9343 - val_loss: 0.9301 - lr: 0.0010
# Epoch 16/500
# 1/1 [==============================] - 0s 289ms/step - loss: 0.9301 - val_loss: 0.9083 - lr: 0.0010
# Epoch 17/500
# 1/1 [==============================] - 0s 314ms/step - loss: 0.9083 - val_loss: 0.9217 - lr: 0.0010
# Epoch 18/500
# 1/1 [==============================] - 0s 284ms/step - loss: 0.9217 - val_loss: 0.9404 - lr: 0.0010
# Epoch 19/500
# 1/1 [==============================] - 0s 282ms/step - loss: 0.9404 - val_loss: 0.8998 - lr: 0.0010
# Epoch 20/500
# 1/1 [==============================] - 0s 280ms/step - loss: 0.8998 - val_loss: 0.9215 - lr: 0.0010
# Epoch 21/500
# 1/1 [==============================] - 0s 280ms/step - loss: 0.9215 - val_loss: 0.8981 - lr: 0.0010
# Epoch 22/500
# 1/1 [==============================] - 0s 279ms/step - loss: 0.8981 - val_loss: 0.8750 - lr: 0.0010
# Epoch 23/500
# 1/1 [==============================] - 0s 271ms/step - loss: 0.8750 - val_loss: 0.8805 - lr: 0.0010
# Epoch 24/500
# 1/1 [==============================] - 0s 280ms/step - loss: 0.8805 - val_loss: 0.8675 - lr: 0.0010
# Epoch 25/500
# 1/1 [==============================] - 0s 273ms/step - loss: 0.8675 - val_loss: 0.8655 - lr: 0.0010
# Epoch 26/500
# 1/1 [==============================] - 0s 288ms/step - loss: 0.8655 - val_loss: 0.8446 - lr: 0.0010
# Epoch 27/500
# 1/1 [==============================] - 0s 304ms/step - loss: 0.8446 - val_loss: 0.8427 - lr: 0.0010
# Epoch 28/500
# 1/1 [==============================] - 0s 365ms/step - loss: 0.8427 - val_loss: 0.8341 - lr: 0.0010
# Epoch 29/500
# 1/1 [==============================] - 0s 336ms/step - loss: 0.8341 - val_loss: 0.8209 - lr: 0.0010
# Epoch 30/500
# 1/1 [==============================] - 0s 297ms/step - loss: 0.8209 - val_loss: 0.8145 - lr: 0.0010
# Epoch 31/500
# 1/1 [==============================] - 0s 454ms/step - loss: 0.8145 - val_loss: 0.8071 - lr: 0.0010
# Epoch 32/500
# 1/1 [==============================] - 0s 327ms/step - loss: 0.8071 - val_loss: 0.7961 - lr: 0.0010
# Epoch 33/500
# 1/1 [==============================] - 0s 269ms/step - loss: 0.7961 - val_loss: 0.7917 - lr: 0.0010
# Epoch 34/500
# 1/1 [==============================] - 0s 268ms/step - loss: 0.7917 - val_loss: 0.8020 - lr: 0.0010
# Epoch 35/500
# 1/1 [==============================] - 0s 266ms/step - loss: 0.8020 - val_loss: 0.8178 - lr: 0.0010
# Epoch 36/500
# 1/1 [==============================] - 0s 271ms/step - loss: 0.8178 - val_loss: 0.7822 - lr: 0.0010
# Epoch 37/500
# 1/1 [==============================] - 0s 288ms/step - loss: 0.7822 - val_loss: 0.8052 - lr: 0.0010
# Epoch 38/500
# 1/1 [==============================] - 0s 383ms/step - loss: 0.8052 - val_loss: 0.7628 - lr: 0.0010
# Epoch 39/500
# 1/1 [==============================] - 0s 463ms/step - loss: 0.7628 - val_loss: 0.7848 - lr: 0.0010
# Epoch 40/500
# 1/1 [==============================] - 0s 352ms/step - loss: 0.7848 - val_loss: 0.7585 - lr: 0.0010
# Epoch 41/500
# 1/1 [==============================] - 0s 388ms/step - loss: 0.7585 - val_loss: 0.7729 - lr: 0.0010
# Epoch 42/500
# 1/1 [==============================] - 0s 317ms/step - loss: 0.7729 - val_loss: 0.7557 - lr: 0.0010
# Epoch 43/500
# 1/1 [==============================] - 0s 317ms/step - loss: 0.7557 - val_loss: 0.7629 - lr: 0.0010
# Epoch 44/500
# 1/1 [==============================] - 0s 277ms/step - loss: 0.7629 - val_loss: 0.7480 - lr: 0.0010
# Epoch 45/500
# 1/1 [==============================] - 0s 258ms/step - loss: 0.7480 - val_loss: 0.7504 - lr: 0.0010
# Epoch 46/500
# 1/1 [==============================] - 0s 263ms/step - loss: 0.7504 - val_loss: 0.7439 - lr: 0.0010
# Epoch 47/500
# 1/1 [==============================] - 0s 265ms/step - loss: 0.7439 - val_loss: 0.7420 - lr: 0.0010
# Epoch 48/500
# 1/1 [==============================] - 0s 267ms/step - loss: 0.7420 - val_loss: 0.7353 - lr: 0.0010
# Epoch 49/500
# 1/1 [==============================] - 0s 277ms/step - loss: 0.7353 - val_loss: 0.7303 - lr: 0.0010
# Epoch 50/500
# 1/1 [==============================] - 0s 274ms/step - loss: 0.7303 - val_loss: 0.7263 - lr: 0.0010
# Epoch 51/500
# 1/1 [==============================] - 0s 272ms/step - loss: 0.7263 - val_loss: 0.7246 - lr: 0.0010
# Epoch 52/500
# 1/1 [==============================] - 0s 275ms/step - loss: 0.7246 - val_loss: 0.7173 - lr: 0.0010
# Epoch 53/500
# 1/1 [==============================] - 0s 277ms/step - loss: 0.7173 - val_loss: 0.7171 - lr: 0.0010
# Epoch 54/500
# 1/1 [==============================] - 0s 290ms/step - loss: 0.7171 - val_loss: 0.7100 - lr: 0.0010
# Epoch 55/500
# 1/1 [==============================] - 0s 271ms/step - loss: 0.7100 - val_loss: 0.7078 - lr: 0.0010
# Epoch 56/500
# 1/1 [==============================] - 0s 272ms/step - loss: 0.7078 - val_loss: 0.7034 - lr: 0.0010
# Epoch 57/500
# 1/1 [==============================] - 0s 365ms/step - loss: 0.7034 - val_loss: 0.6998 - lr: 0.0010
# Epoch 58/500
# 1/1 [==============================] - 0s 302ms/step - loss: 0.6998 - val_loss: 0.6972 - lr: 0.0010
# Epoch 59/500
# 1/1 [==============================] - 0s 272ms/step - loss: 0.6972 - val_loss: 0.6915 - lr: 0.0010
# Epoch 60/500
# 1/1 [==============================] - 0s 306ms/step - loss: 0.6915 - val_loss: 0.6868 - lr: 0.0010
# Epoch 61/500
# 1/1 [==============================] - 0s 280ms/step - loss: 0.6868 - val_loss: 0.6881 - lr: 0.0010
# Epoch 62/500
# 1/1 [==============================] - 0s 281ms/step - loss: 0.6881 - val_loss: 0.6801 - lr: 0.0010
# Epoch 63/500
# 1/1 [==============================] - 0s 279ms/step - loss: 0.6801 - val_loss: 0.6707 - lr: 0.0010
# Epoch 64/500
# 1/1 [==============================] - 0s 338ms/step - loss: 0.6707 - val_loss: 0.6708 - lr: 0.0010
# Epoch 65/500
# 1/1 [==============================] - 0s 395ms/step - loss: 0.6708 - val_loss: 0.6716 - lr: 0.0010
# Epoch 66/500
# 1/1 [==============================] - 0s 300ms/step - loss: 0.6716 - val_loss: 0.6600 - lr: 0.0010
# Epoch 67/500
# 1/1 [==============================] - 0s 282ms/step - loss: 0.6600 - val_loss: 0.6535 - lr: 0.0010
# Epoch 68/500
# 1/1 [==============================] - 0s 283ms/step - loss: 0.6535 - val_loss: 0.6796 - lr: 0.0010
# Epoch 69/500
# 1/1 [==============================] - 0s 273ms/step - loss: 0.6796 - val_loss: 0.7024 - lr: 0.0010
# Epoch 70/500
# 1/1 [==============================] - 0s 277ms/step - loss: 0.7024 - val_loss: 0.6718 - lr: 0.0010
# Epoch 71/500
# 1/1 [==============================] - 0s 297ms/step - loss: 0.6718 - val_loss: 0.6611 - lr: 0.0010
# Epoch 72/500
# 1/1 [==============================] - 0s 276ms/step - loss: 0.6611 - val_loss: 0.6581 - lr: 0.0010
# Epoch 73/500
# 1/1 [==============================] - 0s 282ms/step - loss: 0.6581 - val_loss: 0.6362 - lr: 0.0010
# Epoch 74/500
# 1/1 [==============================] - 0s 280ms/step - loss: 0.6362 - val_loss: 0.6435 - lr: 0.0010
# Epoch 75/500
# 1/1 [==============================] - 0s 325ms/step - loss: 0.6435 - val_loss: 0.6214 - lr: 0.0010
# Epoch 76/500
# 1/1 [==============================] - 0s 355ms/step - loss: 0.6214 - val_loss: 0.6303 - lr: 0.0010
# Epoch 77/500
# 1/1 [==============================] - 1s 529ms/step - loss: 0.6303 - val_loss: 0.6185 - lr: 0.0010
# Epoch 78/500
# 1/1 [==============================] - 0s 405ms/step - loss: 0.6185 - val_loss: 0.6113 - lr: 0.0010
# Epoch 79/500
# 1/1 [==============================] - 0s 301ms/step - loss: 0.6113 - val_loss: 0.6053 - lr: 0.0010
# Epoch 80/500
# 1/1 [==============================] - 0s 258ms/step - loss: 0.6053 - val_loss: 0.6014 - lr: 0.0010
# Epoch 81/500
# 1/1 [==============================] - 0s 260ms/step - loss: 0.6014 - val_loss: 0.5955 - lr: 0.0010
# Epoch 82/500
# 1/1 [==============================] - 0s 353ms/step - loss: 0.5955 - val_loss: 0.5944 - lr: 0.0010
# Epoch 83/500
# 1/1 [==============================] - 0s 268ms/step - loss: 0.5944 - val_loss: 0.6045 - lr: 0.0010
# Epoch 84/500
# 1/1 [==============================] - 0s 287ms/step - loss: 0.6045 - val_loss: 0.6463 - lr: 0.0010
# Epoch 85/500
# 1/1 [==============================] - 0s 277ms/step - loss: 0.6463 - val_loss: 0.6354 - lr: 0.0010
# Epoch 86/500
# 1/1 [==============================] - 0s 308ms/step - loss: 0.6354 - val_loss: 0.5959 - lr: 0.0010
# Epoch 87/500
# 1/1 [==============================] - 0s 276ms/step - loss: 0.5959 - val_loss: 0.6717 - lr: 0.0010
# Epoch 88/500
# 1/1 [==============================] - 0s 304ms/step - loss: 0.6717 - val_loss: 0.5821 - lr: 0.0010
# Epoch 89/500
# 1/1 [==============================] - 0s 252ms/step - loss: 0.5821 - val_loss: 0.5917 - lr: 0.0010
# Epoch 90/500
# 1/1 [==============================] - 0s 306ms/step - loss: 0.5917 - val_loss: 0.6029 - lr: 0.0010
# Epoch 91/500
# 1/1 [==============================] - 0s 253ms/step - loss: 0.6029 - val_loss: 0.5703 - lr: 0.0010
# Epoch 92/500
# 1/1 [==============================] - 0s 246ms/step - loss: 0.5703 - val_loss: 0.5868 - lr: 0.0010
# Epoch 93/500
# 1/1 [==============================] - 0s 246ms/step - loss: 0.5868 - val_loss: 0.5902 - lr: 0.0010
# Epoch 94/500
# 1/1 [==============================] - 0s 276ms/step - loss: 0.5902 - val_loss: 0.5613 - lr: 0.0010
# Epoch 95/500
# 1/1 [==============================] - 0s 287ms/step - loss: 0.5613 - val_loss: 0.5627 - lr: 0.0010
# Epoch 96/500
# 1/1 [==============================] - 0s 272ms/step - loss: 0.5627 - val_loss: 0.5807 - lr: 0.0010
# Epoch 97/500
# 1/1 [==============================] - 0s 301ms/step - loss: 0.5807 - val_loss: 0.5591 - lr: 0.0010
# Epoch 98/500
# 1/1 [==============================] - 0s 282ms/step - loss: 0.5591 - val_loss: 0.5428 - lr: 0.0010
# Epoch 99/500
# 1/1 [==============================] - 0s 244ms/step - loss: 0.5428 - val_loss: 0.5463 - lr: 0.0010
# Epoch 100/500
# 1/1 [==============================] - 0s 265ms/step - loss: 0.5463 - val_loss: 0.5458 - lr: 0.0010
# Epoch 101/500
# 1/1 [==============================] - 0s 294ms/step - loss: 0.5458 - val_loss: 0.5531 - lr: 0.0010
# Epoch 102/500
# 1/1 [==============================] - 0s 354ms/step - loss: 0.5531 - val_loss: 0.5589 - lr: 0.0010
# Epoch 103/500
# 1/1 [==============================] - 0s 247ms/step - loss: 0.5589 - val_loss: 0.5434 - lr: 0.0010
# Epoch 104/500
# 1/1 [==============================] - 0s 248ms/step - loss: 0.5434 - val_loss: 0.5243 - lr: 0.0010
# Epoch 105/500
# 1/1 [==============================] - 0s 308ms/step - loss: 0.5243 - val_loss: 0.5380 - lr: 0.0010
# Epoch 106/500
# 1/1 [==============================] - 0s 247ms/step - loss: 0.5380 - val_loss: 0.5605 - lr: 0.0010
# Epoch 107/500
# 1/1 [==============================] - 0s 247ms/step - loss: 0.5605 - val_loss: 0.5330 - lr: 0.0010
# Epoch 108/500
# 1/1 [==============================] - 0s 252ms/step - loss: 0.5330 - val_loss: 0.5157 - lr: 0.0010
# Epoch 109/500
# 1/1 [==============================] - 0s 294ms/step - loss: 0.5157 - val_loss: 0.5272 - lr: 0.0010
# Epoch 110/500
# 1/1 [==============================] - 0s 243ms/step - loss: 0.5272 - val_loss: 0.5553 - lr: 0.0010
# Epoch 111/500
# 1/1 [==============================] - 0s 246ms/step - loss: 0.5553 - val_loss: 0.5219 - lr: 0.0010
# Epoch 112/500
# 1/1 [==============================] - 0s 307ms/step - loss: 0.5219 - val_loss: 0.5082 - lr: 0.0010
# Epoch 113/500
# 1/1 [==============================] - 0s 255ms/step - loss: 0.5082 - val_loss: 0.5071 - lr: 0.0010
# Epoch 114/500
# 1/1 [==============================] - 0s 249ms/step - loss: 0.5071 - val_loss: 0.5206 - lr: 0.0010
# Epoch 115/500
# 1/1 [==============================] - 0s 252ms/step - loss: 0.5206 - val_loss: 0.4991 - lr: 0.0010
# Epoch 116/500
# 1/1 [==============================] - 0s 253ms/step - loss: 0.4991 - val_loss: 0.4924 - lr: 0.0010
# Epoch 117/500
# 1/1 [==============================] - 0s 249ms/step - loss: 0.4924 - val_loss: 0.4831 - lr: 0.0010
# Epoch 118/500
# 1/1 [==============================] - 0s 249ms/step - loss: 0.4831 - val_loss: 0.4894 - lr: 0.0010
# Epoch 119/500
# 1/1 [==============================] - 0s 270ms/step - loss: 0.4894 - val_loss: 0.5105 - lr: 0.0010
# Epoch 120/500
# 1/1 [==============================] - 0s 276ms/step - loss: 0.5105 - val_loss: 0.5339 - lr: 0.0010
# Epoch 121/500
# 1/1 [==============================] - 0s 279ms/step - loss: 0.5339 - val_loss: 0.4998 - lr: 0.0010
# Epoch 122/500
# 1/1 [==============================] - 0s 262ms/step - loss: 0.4998 - val_loss: 0.4703 - lr: 0.0010
# Epoch 123/500
# 1/1 [==============================] - 0s 247ms/step - loss: 0.4703 - val_loss: 0.4856 - lr: 0.0010
# Epoch 124/500
# 1/1 [==============================] - 0s 248ms/step - loss: 0.4856 - val_loss: 0.5213 - lr: 0.0010
# Epoch 125/500
# 1/1 [==============================] - 0s 244ms/step - loss: 0.5213 - val_loss: 0.5047 - lr: 0.0010
# Epoch 126/500
# 1/1 [==============================] - 0s 250ms/step - loss: 0.5047 - val_loss: 0.4684 - lr: 0.0010
# Epoch 127/500
# 1/1 [==============================] - 0s 257ms/step - loss: 0.4684 - val_loss: 0.5104 - lr: 0.0010
# Epoch 128/500
# 1/1 [==============================] - 0s 246ms/step - loss: 0.5104 - val_loss: 0.5147 - lr: 0.0010
# Epoch 129/500
# 1/1 [==============================] - 0s 247ms/step - loss: 0.5147 - val_loss: 0.4724 - lr: 0.0010
# Epoch 130/500
# 1/1 [==============================] - 0s 245ms/step - loss: 0.4724 - val_loss: 0.4967 - lr: 0.0010
# Epoch 131/500
# 1/1 [==============================] - 0s 248ms/step - loss: 0.4967 - val_loss: 0.5056 - lr: 0.0010
# Epoch 132/500
# 1/1 [==============================] - 0s 250ms/step - loss: 0.5056 - val_loss: 0.4630 - lr: 0.0010
# Epoch 133/500
# 1/1 [==============================] - 0s 245ms/step - loss: 0.4630 - val_loss: 0.4790 - lr: 0.0010
# Epoch 134/500
# 1/1 [==============================] - 0s 247ms/step - loss: 0.4790 - val_loss: 0.4857 - lr: 0.0010
# Epoch 135/500
# 1/1 [==============================] - 0s 255ms/step - loss: 0.4857 - val_loss: 0.4595 - lr: 0.0010
# Epoch 136/500
# 1/1 [==============================] - 0s 259ms/step - loss: 0.4595 - val_loss: 0.4547 - lr: 0.0010
# Epoch 137/500
# 1/1 [==============================] - 0s 271ms/step - loss: 0.4547 - val_loss: 0.4795 - lr: 0.0010
# Epoch 138/500
# 1/1 [==============================] - 0s 257ms/step - loss: 0.4795 - val_loss: 0.4525 - lr: 0.0010
# Epoch 139/500
# 1/1 [==============================] - 0s 311ms/step - loss: 0.4525 - val_loss: 0.4422 - lr: 0.0010
# Epoch 140/500
# 1/1 [==============================] - 0s 280ms/step - loss: 0.4422 - val_loss: 0.4724 - lr: 0.0010
# Epoch 141/500
# 1/1 [==============================] - 0s 308ms/step - loss: 0.4724 - val_loss: 0.4467 - lr: 0.0010
# Epoch 142/500
# 1/1 [==============================] - 0s 348ms/step - loss: 0.4467 - val_loss: 0.4350 - lr: 0.0010
# Epoch 143/500
# 1/1 [==============================] - 0s 270ms/step - loss: 0.4350 - val_loss: 0.4375 - lr: 0.0010
# Epoch 144/500
# 1/1 [==============================] - 0s 262ms/step - loss: 0.4375 - val_loss: 0.4453 - lr: 0.0010
# Epoch 145/500
# 1/1 [==============================] - 0s 312ms/step - loss: 0.4453 - val_loss: 0.4407 - lr: 0.0010
# Epoch 146/500
# 1/1 [==============================] - 0s 325ms/step - loss: 0.4407 - val_loss: 0.4267 - lr: 0.0010
# Epoch 147/500
# 1/1 [==============================] - 0s 267ms/step - loss: 0.4267 - val_loss: 0.4166 - lr: 0.0010
# Epoch 148/500
# 1/1 [==============================] - 0s 312ms/step - loss: 0.4166 - val_loss: 0.4154 - lr: 0.0010
# Epoch 149/500
# 1/1 [==============================] - 0s 259ms/step - loss: 0.4154 - val_loss: 0.4200 - lr: 0.0010
# Epoch 150/500
# 1/1 [==============================] - 0s 270ms/step - loss: 0.4200 - val_loss: 0.4268 - lr: 0.0010
# Epoch 151/500
# 1/1 [==============================] - 0s 304ms/step - loss: 0.4268 - val_loss: 0.4175 - lr: 0.0010
# Epoch 152/500
# 1/1 [==============================] - 0s 256ms/step - loss: 0.4175 - val_loss: 0.4159 - lr: 0.0010
# Epoch 153/500
# 1/1 [==============================] - 0s 271ms/step - loss: 0.4159 - val_loss: 0.4096 - lr: 0.0010
# Epoch 154/500
# 1/1 [==============================] - 0s 263ms/step - loss: 0.4096 - val_loss: 0.4112 - lr: 0.0010
# Epoch 155/500
# 1/1 [==============================] - 0s 294ms/step - loss: 0.4112 - val_loss: 0.4054 - lr: 0.0010
# Epoch 156/500
# 1/1 [==============================] - 0s 265ms/step - loss: 0.4054 - val_loss: 0.4049 - lr: 0.0010
# Epoch 157/500
# 1/1 [==============================] - 0s 280ms/step - loss: 0.4049 - val_loss: 0.4161 - lr: 0.0010
# Epoch 158/500
# 1/1 [==============================] - 0s 258ms/step - loss: 0.4161 - val_loss: 0.4234 - lr: 0.0010
# Epoch 159/500
# 1/1 [==============================] - 0s 274ms/step - loss: 0.4234 - val_loss: 0.4195 - lr: 0.0010
# Epoch 160/500
# 1/1 [==============================] - 0s 259ms/step - loss: 0.4195 - val_loss: 0.4159 - lr: 0.0010
# Epoch 161/500
# 1/1 [==============================] - 0s 273ms/step - loss: 0.4159 - val_loss: 0.3920 - lr: 0.0010
# Epoch 162/500
# 1/1 [==============================] - 0s 252ms/step - loss: 0.3920 - val_loss: 0.3807 - lr: 0.0010
# Epoch 163/500
# 1/1 [==============================] - 0s 264ms/step - loss: 0.3807 - val_loss: 0.3795 - lr: 0.0010
# Epoch 164/500
# 1/1 [==============================] - 0s 252ms/step - loss: 0.3795 - val_loss: 0.3820 - lr: 0.0010
# Epoch 165/500
# 1/1 [==============================] - 0s 252ms/step - loss: 0.3820 - val_loss: 0.3932 - lr: 0.0010
# Epoch 166/500
# 1/1 [==============================] - 0s 250ms/step - loss: 0.3932 - val_loss: 0.4122 - lr: 0.0010
# Epoch 167/500
# 1/1 [==============================] - 0s 254ms/step - loss: 0.4122 - val_loss: 0.4365 - lr: 0.0010
# Epoch 168/500
# 1/1 [==============================] - 0s 250ms/step - loss: 0.4365 - val_loss: 0.4046 - lr: 0.0010
# Epoch 169/500
# 1/1 [==============================] - 0s 285ms/step - loss: 0.4046 - val_loss: 0.3776 - lr: 0.0010
# Epoch 170/500
# 1/1 [==============================] - 0s 304ms/step - loss: 0.3776 - val_loss: 0.3732 - lr: 0.0010
# Epoch 171/500
# 1/1 [==============================] - 0s 317ms/step - loss: 0.3732 - val_loss: 0.3762 - lr: 0.0010
# Epoch 172/500
# 1/1 [==============================] - 0s 323ms/step - loss: 0.3762 - val_loss: 0.3844 - lr: 0.0010
# Epoch 173/500
# 1/1 [==============================] - 0s 303ms/step - loss: 0.3844 - val_loss: 0.3957 - lr: 0.0010
# Epoch 174/500
# 1/1 [==============================] - 0s 293ms/step - loss: 0.3957 - val_loss: 0.3999 - lr: 0.0010
# Epoch 175/500
# 1/1 [==============================] - 0s 299ms/step - loss: 0.3999 - val_loss: 0.3669 - lr: 0.0010
# Epoch 176/500
# 1/1 [==============================] - 0s 276ms/step - loss: 0.3669 - val_loss: 0.3673 - lr: 0.0010
# Epoch 177/500
# 1/1 [==============================] - 0s 299ms/step - loss: 0.3673 - val_loss: 0.3664 - lr: 0.0010
# Epoch 178/500
# 1/1 [==============================] - 0s 275ms/step - loss: 0.3664 - val_loss: 0.3780 - lr: 0.0010
# Epoch 179/500
# 1/1 [==============================] - 0s 318ms/step - loss: 0.3780 - val_loss: 0.3969 - lr: 0.0010
# Epoch 180/500
# 1/1 [==============================] - 0s 349ms/step - loss: 0.3969 - val_loss: 0.3787 - lr: 0.0010
# Epoch 181/500
# 1/1 [==============================] - 0s 319ms/step - loss: 0.3787 - val_loss: 0.3756 - lr: 0.0010
# Epoch 182/500
# 1/1 [==============================] - 0s 321ms/step - loss: 0.3756 - val_loss: 0.3559 - lr: 0.0010
# Epoch 183/500
# 1/1 [==============================] - 0s 266ms/step - loss: 0.3559 - val_loss: 0.3596 - lr: 0.0010
# Epoch 184/500
# 1/1 [==============================] - 0s 300ms/step - loss: 0.3596 - val_loss: 0.3508 - lr: 0.0010
# Epoch 185/500
# 1/1 [==============================] - 0s 260ms/step - loss: 0.3508 - val_loss: 0.3572 - lr: 0.0010
# Epoch 186/500
# 1/1 [==============================] - 0s 282ms/step - loss: 0.3572 - val_loss: 0.3576 - lr: 0.0010
# Epoch 187/500
# 1/1 [==============================] - 0s 255ms/step - loss: 0.3576 - val_loss: 0.3657 - lr: 0.0010
# Epoch 188/500
# 1/1 [==============================] - 0s 247ms/step - loss: 0.3657 - val_loss: 0.3691 - lr: 0.0010
# Epoch 189/500
# 1/1 [==============================] - 0s 256ms/step - loss: 0.3691 - val_loss: 0.3604 - lr: 0.0010
# Epoch 190/500
# 1/1 [==============================] - 0s 314ms/step - loss: 0.3604 - val_loss: 0.3533 - lr: 0.0010
# Epoch 191/500
# 1/1 [==============================] - 0s 259ms/step - loss: 0.3533 - val_loss: 0.3488 - lr: 0.0010
# Epoch 192/500
# 1/1 [==============================] - 0s 255ms/step - loss: 0.3488 - val_loss: 0.3444 - lr: 0.0010
# Epoch 193/500
# 1/1 [==============================] - 0s 267ms/step - loss: 0.3444 - val_loss: 0.3429 - lr: 0.0010
# Epoch 194/500
# 1/1 [==============================] - 0s 257ms/step - loss: 0.3429 - val_loss: 0.3367 - lr: 0.0010
# Epoch 195/500
# 1/1 [==============================] - 0s 259ms/step - loss: 0.3367 - val_loss: 0.3305 - lr: 0.0010
# Epoch 196/500
# 1/1 [==============================] - 0s 252ms/step - loss: 0.3305 - val_loss: 0.3307 - lr: 0.0010
# Epoch 197/500
# 1/1 [==============================] - 0s 284ms/step - loss: 0.3307 - val_loss: 0.3277 - lr: 0.0010
# Epoch 198/500
# 1/1 [==============================] - 0s 249ms/step - loss: 0.3277 - val_loss: 0.3281 - lr: 0.0010
# Epoch 199/500
# 1/1 [==============================] - 0s 253ms/step - loss: 0.3281 - val_loss: 0.3375 - lr: 0.0010
# Epoch 200/500
# 1/1 [==============================] - 0s 254ms/step - loss: 0.3375 - val_loss: 0.3605 - lr: 0.0010
# Epoch 201/500
# 1/1 [==============================] - 0s 256ms/step - loss: 0.3605 - val_loss: 0.3630 - lr: 0.0010
# Epoch 202/500
# 1/1 [==============================] - 0s 248ms/step - loss: 0.3630 - val_loss: 0.3837 - lr: 0.0010
# Epoch 203/500
# 1/1 [==============================] - 0s 250ms/step - loss: 0.3837 - val_loss: 0.3665 - lr: 0.0010
# Epoch 204/500
# 1/1 [==============================] - 0s 252ms/step - loss: 0.3665 - val_loss: 0.3315 - lr: 0.0010
# Epoch 205/500
# 1/1 [==============================] - 0s 293ms/step - loss: 0.3315 - val_loss: 0.3263 - lr: 0.0010
# Epoch 206/500
# 1/1 [==============================] - 0s 257ms/step - loss: 0.3263 - val_loss: 0.3194 - lr: 0.0010
# Epoch 207/500
# 1/1 [==============================] - 0s 258ms/step - loss: 0.3194 - val_loss: 0.3245 - lr: 0.0010
# Epoch 208/500
# 1/1 [==============================] - 0s 255ms/step - loss: 0.3245 - val_loss: 0.3272 - lr: 0.0010
# Epoch 209/500
# 1/1 [==============================] - 0s 250ms/step - loss: 0.3272 - val_loss: 0.3446 - lr: 0.0010
# Epoch 210/500
# 1/1 [==============================] - 0s 249ms/step - loss: 0.3446 - val_loss: 0.3231 - lr: 0.0010
# Epoch 211/500
# 1/1 [==============================] - 0s 258ms/step - loss: 0.3231 - val_loss: 0.3155 - lr: 0.0010
# Epoch 212/500
# 1/1 [==============================] - 0s 300ms/step - loss: 0.3155 - val_loss: 0.3033 - lr: 0.0010
# Epoch 213/500
# 1/1 [==============================] - 0s 363ms/step - loss: 0.3033 - val_loss: 0.3042 - lr: 0.0010
# Epoch 214/500
# 1/1 [==============================] - 0s 300ms/step - loss: 0.3042 - val_loss: 0.2958 - lr: 0.0010
# Epoch 215/500
# 1/1 [==============================] - 0s 283ms/step - loss: 0.2958 - val_loss: 0.2941 - lr: 0.0010
# Epoch 216/500
# 1/1 [==============================] - 0s 258ms/step - loss: 0.2941 - val_loss: 0.2976 - lr: 0.0010
# Epoch 217/500
# 1/1 [==============================] - 0s 254ms/step - loss: 0.2976 - val_loss: 0.2959 - lr: 0.0010
# Epoch 218/500
# 1/1 [==============================] - 0s 263ms/step - loss: 0.2959 - val_loss: 0.3183 - lr: 0.0010
# Epoch 219/500
# 1/1 [==============================] - 0s 250ms/step - loss: 0.3183 - val_loss: 0.3778 - lr: 0.0010
# Epoch 220/500
# 1/1 [==============================] - 0s 293ms/step - loss: 0.3778 - val_loss: 0.3855 - lr: 0.0010
# Epoch 221/500
# 1/1 [==============================] - 0s 255ms/step - loss: 0.3855 - val_loss: 0.3012 - lr: 0.0010
# Epoch 222/500
# 1/1 [==============================] - 0s 253ms/step - loss: 0.3012 - val_loss: 0.2987 - lr: 0.0010
# Epoch 223/500
# 1/1 [==============================] - 0s 291ms/step - loss: 0.2987 - val_loss: 0.3518 - lr: 0.0010
# Epoch 224/500
# 1/1 [==============================] - 0s 257ms/step - loss: 0.3518 - val_loss: 0.3356 - lr: 0.0010
# Epoch 225/500
# 1/1 [==============================] - 0s 264ms/step - loss: 0.3356 - val_loss: 0.2832 - lr: 0.0010
# Epoch 226/500
# 1/1 [==============================] - 0s 283ms/step - loss: 0.2832 - val_loss: 0.2999 - lr: 0.0010
# Epoch 227/500
# 1/1 [==============================] - 0s 320ms/step - loss: 0.2999 - val_loss: 0.3134 - lr: 0.0010
# Epoch 228/500
# 1/1 [==============================] - 0s 256ms/step - loss: 0.3134 - val_loss: 0.3124 - lr: 0.0010
# Epoch 229/500
# 1/1 [==============================] - 0s 290ms/step - loss: 0.3124 - val_loss: 0.2781 - lr: 0.0010
# Epoch 230/500
# 1/1 [==============================] - 0s 289ms/step - loss: 0.2781 - val_loss: 0.2797 - lr: 0.0010
# Epoch 231/500
# 1/1 [==============================] - 0s 287ms/step - loss: 0.2797 - val_loss: 0.3046 - lr: 0.0010
# Epoch 232/500
# 1/1 [==============================] - 0s 259ms/step - loss: 0.3046 - val_loss: 0.2892 - lr: 0.0010
# Epoch 233/500
# 1/1 [==============================] - 0s 256ms/step - loss: 0.2892 - val_loss: 0.2709 - lr: 0.0010
# Epoch 234/500
# 1/1 [==============================] - 0s 321ms/step - loss: 0.2709 - val_loss: 0.2647 - lr: 0.0010
# Epoch 235/500
# 1/1 [==============================] - 0s 285ms/step - loss: 0.2647 - val_loss: 0.2814 - lr: 0.0010
# Epoch 236/500
# 1/1 [==============================] - 0s 284ms/step - loss: 0.2814 - val_loss: 0.2918 - lr: 0.0010
# Epoch 237/500
# 1/1 [==============================] - 0s 261ms/step - loss: 0.2918 - val_loss: 0.2897 - lr: 0.0010
# Epoch 238/500
# 1/1 [==============================] - 0s 302ms/step - loss: 0.2897 - val_loss: 0.2558 - lr: 0.0010
# Epoch 239/500
# 1/1 [==============================] - 0s 306ms/step - loss: 0.2558 - val_loss: 0.2549 - lr: 0.0010
# Epoch 240/500
# 1/1 [==============================] - 0s 294ms/step - loss: 0.2549 - val_loss: 0.2735 - lr: 0.0010
# Epoch 241/500
# 1/1 [==============================] - 0s 278ms/step - loss: 0.2735 - val_loss: 0.2895 - lr: 0.0010
# Epoch 242/500
# 1/1 [==============================] - 0s 278ms/step - loss: 0.2895 - val_loss: 0.2688 - lr: 0.0010
# Epoch 243/500
# 1/1 [==============================] - 0s 319ms/step - loss: 0.2688 - val_loss: 0.2522 - lr: 0.0010
# Epoch 244/500
# 1/1 [==============================] - 0s 338ms/step - loss: 0.2522 - val_loss: 0.2468 - lr: 0.0010
# Epoch 245/500
# 1/1 [==============================] - 0s 298ms/step - loss: 0.2468 - val_loss: 0.2642 - lr: 0.0010
# Epoch 246/500
# 1/1 [==============================] - 0s 339ms/step - loss: 0.2642 - val_loss: 0.2745 - lr: 0.0010
# Epoch 247/500
# 1/1 [==============================] - 0s 261ms/step - loss: 0.2745 - val_loss: 0.2625 - lr: 0.0010
# Epoch 248/500
# 1/1 [==============================] - 0s 335ms/step - loss: 0.2625 - val_loss: 0.2465 - lr: 0.0010
# Epoch 249/500
# 1/1 [==============================] - 0s 265ms/step - loss: 0.2465 - val_loss: 0.2321 - lr: 0.0010
# Epoch 250/500
# 1/1 [==============================] - 0s 255ms/step - loss: 0.2321 - val_loss: 0.2392 - lr: 0.0010
# Epoch 251/500
# 1/1 [==============================] - 0s 430ms/step - loss: 0.2392 - val_loss: 0.2521 - lr: 0.0010
# Epoch 252/500
# 1/1 [==============================] - 0s 287ms/step - loss: 0.2521 - val_loss: 0.2565 - lr: 0.0010
# Epoch 253/500
# 1/1 [==============================] - 0s 341ms/step - loss: 0.2565 - val_loss: 0.2583 - lr: 0.0010
# Epoch 254/500
# 1/1 [==============================] - 0s 283ms/step - loss: 0.2583 - val_loss: 0.2439 - lr: 0.0010
# Epoch 255/500
# 1/1 [==============================] - 0s 287ms/step - loss: 0.2439 - val_loss: 0.2376 - lr: 0.0010
# Epoch 256/500
# 1/1 [==============================] - 0s 284ms/step - loss: 0.2376 - val_loss: 0.2198 - lr: 0.0010
# Epoch 257/500
# 1/1 [==============================] - 0s 293ms/step - loss: 0.2198 - val_loss: 0.2274 - lr: 0.0010
# Epoch 258/500
# 1/1 [==============================] - 0s 496ms/step - loss: 0.2274 - val_loss: 0.2359 - lr: 0.0010
# Epoch 259/500
# 1/1 [==============================] - 0s 307ms/step - loss: 0.2359 - val_loss: 0.2390 - lr: 0.0010
# Epoch 260/500
# 1/1 [==============================] - 0s 289ms/step - loss: 0.2390 - val_loss: 0.2464 - lr: 0.0010
# Epoch 261/500
# 1/1 [==============================] - 0s 290ms/step - loss: 0.2464 - val_loss: 0.2348 - lr: 0.0010
# Epoch 262/500
# 1/1 [==============================] - 0s 288ms/step - loss: 0.2348 - val_loss: 0.2409 - lr: 0.0010
# Epoch 263/500
# 1/1 [==============================] - 0s 288ms/step - loss: 0.2409 - val_loss: 0.2119 - lr: 0.0010
# Epoch 264/500
# 1/1 [==============================] - 0s 281ms/step - loss: 0.2119 - val_loss: 0.2192 - lr: 0.0010
# Epoch 265/500
# 1/1 [==============================] - 0s 321ms/step - loss: 0.2192 - val_loss: 0.2218 - lr: 0.0010
# Epoch 266/500
# 1/1 [==============================] - 0s 296ms/step - loss: 0.2218 - val_loss: 0.2378 - lr: 0.0010
# Epoch 267/500
# 1/1 [==============================] - 0s 281ms/step - loss: 0.2378 - val_loss: 0.2585 - lr: 0.0010
# Epoch 268/500
# 1/1 [==============================] - 0s 281ms/step - loss: 0.2585 - val_loss: 0.2467 - lr: 0.0010
# Epoch 269/500
# 1/1 [==============================] - 0s 284ms/step - loss: 0.2467 - val_loss: 0.2333 - lr: 0.0010
# Epoch 270/500
# 1/1 [==============================] - 0s 300ms/step - loss: 0.2333 - val_loss: 0.2080 - lr: 0.0010
# Epoch 271/500
# 1/1 [==============================] - 0s 292ms/step - loss: 0.2080 - val_loss: 0.2504 - lr: 0.0010
# Epoch 272/500
# 1/1 [==============================] - 0s 323ms/step - loss: 0.2504 - val_loss: 0.2357 - lr: 0.0010
# Epoch 273/500
# 1/1 [==============================] - 0s 291ms/step - loss: 0.2357 - val_loss: 0.2394 - lr: 0.0010
# Epoch 274/500
# 1/1 [==============================] - 0s 285ms/step - loss: 0.2394 - val_loss: 0.2118 - lr: 0.0010
# Epoch 275/500
# 1/1 [==============================] - 0s 284ms/step - loss: 0.2118 - val_loss: 0.2403 - lr: 0.0010
# Epoch 276/500
# 1/1 [==============================] - 0s 283ms/step - loss: 0.2403 - val_loss: 0.2205 - lr: 0.0010
# Epoch 277/500
# 1/1 [==============================] - 0s 282ms/step - loss: 0.2205 - val_loss: 0.2285 - lr: 0.0010
# Epoch 278/500
# 1/1 [==============================] - 0s 313ms/step - loss: 0.2285 - val_loss: 0.2040 - lr: 0.0010
# Epoch 279/500
# 1/1 [==============================] - 0s 357ms/step - loss: 0.2040 - val_loss: 0.2334 - lr: 0.0010
# Epoch 280/500
# 1/1 [==============================] - 0s 289ms/step - loss: 0.2334 - val_loss: 0.2217 - lr: 0.0010
# Epoch 281/500
# 1/1 [==============================] - 0s 283ms/step - loss: 0.2217 - val_loss: 0.2111 - lr: 0.0010
# Epoch 282/500
# 1/1 [==============================] - 0s 307ms/step - loss: 0.2111 - val_loss: 0.2032 - lr: 0.0010
# Epoch 283/500
# 1/1 [==============================] - 0s 289ms/step - loss: 0.2032 - val_loss: 0.2110 - lr: 0.0010
# Epoch 284/500
# 1/1 [==============================] - 0s 283ms/step - loss: 0.2110 - val_loss: 0.2061 - lr: 0.0010
# Epoch 285/500
# 1/1 [==============================] - 0s 297ms/step - loss: 0.2061 - val_loss: 0.1993 - lr: 0.0010
# Epoch 286/500
# 1/1 [==============================] - 0s 311ms/step - loss: 0.1993 - val_loss: 0.1915 - lr: 0.0010
# Epoch 287/500
# 1/1 [==============================] - 0s 298ms/step - loss: 0.1915 - val_loss: 0.1998 - lr: 0.0010
# Epoch 288/500
# 1/1 [==============================] - 0s 281ms/step - loss: 0.1998 - val_loss: 0.1998 - lr: 0.0010
# Epoch 289/500
# 1/1 [==============================] - 0s 285ms/step - loss: 0.1998 - val_loss: 0.2041 - lr: 0.0010
# Epoch 290/500
# 1/1 [==============================] - 0s 284ms/step - loss: 0.2041 - val_loss: 0.1912 - lr: 0.0010
# Epoch 291/500
# 1/1 [==============================] - 0s 284ms/step - loss: 0.1912 - val_loss: 0.1862 - lr: 0.0010
# Epoch 292/500
# 1/1 [==============================] - 0s 295ms/step - loss: 0.1862 - val_loss: 0.1772 - lr: 0.0010
# Epoch 293/500
# 1/1 [==============================] - 0s 289ms/step - loss: 0.1772 - val_loss: 0.1781 - lr: 0.0010
# Epoch 294/500
# 1/1 [==============================] - 0s 290ms/step - loss: 0.1781 - val_loss: 0.1807 - lr: 0.0010
# Epoch 295/500
# 1/1 [==============================] - 0s 280ms/step - loss: 0.1807 - val_loss: 0.1889 - lr: 0.0010
# Epoch 296/500
# 1/1 [==============================] - 0s 341ms/step - loss: 0.1889 - val_loss: 0.1954 - lr: 0.0010
# Epoch 297/500
# 1/1 [==============================] - 0s 286ms/step - loss: 0.1954 - val_loss: 0.2109 - lr: 0.0010
# Epoch 298/500
# 1/1 [==============================] - 0s 283ms/step - loss: 0.2109 - val_loss: 0.1972 - lr: 0.0010
# Epoch 299/500
# 1/1 [==============================] - 0s 285ms/step - loss: 0.1972 - val_loss: 0.1857 - lr: 0.0010
# Epoch 300/500
# 1/1 [==============================] - 0s 284ms/step - loss: 0.1857 - val_loss: 0.1753 - lr: 0.0010
# Epoch 301/500
# 1/1 [==============================] - 0s 302ms/step - loss: 0.1753 - val_loss: 0.1717 - lr: 0.0010
# Epoch 302/500
# 1/1 [==============================] - 0s 293ms/step - loss: 0.1717 - val_loss: 0.1622 - lr: 0.0010
# Epoch 303/500
# 1/1 [==============================] - 0s 294ms/step - loss: 0.1622 - val_loss: 0.1646 - lr: 0.0010
# Epoch 304/500
# 1/1 [==============================] - 0s 326ms/step - loss: 0.1646 - val_loss: 0.1632 - lr: 0.0010
# Epoch 305/500
# 1/1 [==============================] - 0s 283ms/step - loss: 0.1632 - val_loss: 0.1675 - lr: 0.0010
# Epoch 306/500
# 1/1 [==============================] - 0s 291ms/step - loss: 0.1675 - val_loss: 0.1694 - lr: 0.0010
# Epoch 307/500
# 1/1 [==============================] - 0s 297ms/step - loss: 0.1694 - val_loss: 0.1749 - lr: 0.0010
# Epoch 308/500
# 1/1 [==============================] - 0s 293ms/step - loss: 0.1749 - val_loss: 0.1809 - lr: 0.0010
# Epoch 309/500
# 1/1 [==============================] - 0s 306ms/step - loss: 0.1809 - val_loss: 0.1902 - lr: 0.0010
# Epoch 310/500
# 1/1 [==============================] - 0s 306ms/step - loss: 0.1902 - val_loss: 0.2360 - lr: 0.0010
# Epoch 311/500
# 1/1 [==============================] - 0s 285ms/step - loss: 0.2360 - val_loss: 0.2838 - lr: 0.0010
# Epoch 312/500
# 1/1 [==============================] - 0s 285ms/step - loss: 0.2838 - val_loss: 0.2476 - lr: 0.0010
# Epoch 313/500
# 1/1 [==============================] - 0s 285ms/step - loss: 0.2476 - val_loss: 0.1682 - lr: 0.0010
# Epoch 314/500
# 1/1 [==============================] - 0s 288ms/step - loss: 0.1682 - val_loss: 0.1733 - lr: 0.0010
# Epoch 315/500
# 1/1 [==============================] - 0s 291ms/step - loss: 0.1733 - val_loss: 0.2354 - lr: 0.0010
# Epoch 316/500
# 1/1 [==============================] - 0s 294ms/step - loss: 0.2354 - val_loss: 0.2113 - lr: 0.0010
# Epoch 317/500
# 1/1 [==============================] - 0s 304ms/step - loss: 0.2113 - val_loss: 0.1575 - lr: 0.0010
# Epoch 318/500
# 1/1 [==============================] - 0s 300ms/step - loss: 0.1575 - val_loss: 0.1910 - lr: 0.0010
# Epoch 319/500
# 1/1 [==============================] - 0s 313ms/step - loss: 0.1910 - val_loss: 0.2156 - lr: 0.0010
# Epoch 320/500
# 1/1 [==============================] - 0s 309ms/step - loss: 0.2156 - val_loss: 0.1682 - lr: 0.0010
# Epoch 321/500
# 1/1 [==============================] - 0s 286ms/step - loss: 0.1682 - val_loss: 0.1736 - lr: 0.0010
# Epoch 322/500
# 1/1 [==============================] - 0s 289ms/step - loss: 0.1736 - val_loss: 0.1975 - lr: 0.0010
# Epoch 323/500
# 1/1 [==============================] - 0s 287ms/step - loss: 0.1975 - val_loss: 0.1615 - lr: 0.0010
# Epoch 324/500
# 1/1 [==============================] - 0s 286ms/step - loss: 0.1615 - val_loss: 0.1596 - lr: 0.0010
# Epoch 325/500
# 1/1 [==============================] - 0s 280ms/step - loss: 0.1596 - val_loss: 0.1884 - lr: 0.0010
# Epoch 326/500
# 1/1 [==============================] - 0s 295ms/step - loss: 0.1884 - val_loss: 0.1777 - lr: 0.0010
# Epoch 327/500
# 1/1 [==============================] - 0s 288ms/step - loss: 0.1777 - val_loss: 0.1525 - lr: 0.0010
# Epoch 328/500
# 1/1 [==============================] - 0s 324ms/step - loss: 0.1525 - val_loss: 0.1544 - lr: 0.0010
# Epoch 329/500
# 1/1 [==============================] - 0s 315ms/step - loss: 0.1544 - val_loss: 0.1670 - lr: 0.0010
# Epoch 330/500
# 1/1 [==============================] - 0s 299ms/step - loss: 0.1670 - val_loss: 0.1519 - lr: 0.0010
# Epoch 331/500
# 1/1 [==============================] - 0s 288ms/step - loss: 0.1519 - val_loss: 0.1416 - lr: 0.0010
# Epoch 332/500
# 1/1 [==============================] - 0s 298ms/step - loss: 0.1416 - val_loss: 0.1526 - lr: 0.0010
# Epoch 333/500
# 1/1 [==============================] - 0s 292ms/step - loss: 0.1526 - val_loss: 0.1494 - lr: 0.0010
# Epoch 334/500
# 1/1 [==============================] - 0s 290ms/step - loss: 0.1494 - val_loss: 0.1392 - lr: 0.0010
# Epoch 335/500
# 1/1 [==============================] - 0s 291ms/step - loss: 0.1392 - val_loss: 0.1401 - lr: 0.0010
# Epoch 336/500
# 1/1 [==============================] - 0s 287ms/step - loss: 0.1401 - val_loss: 0.1443 - lr: 0.0010
# Epoch 337/500
# 1/1 [==============================] - 0s 286ms/step - loss: 0.1443 - val_loss: 0.1386 - lr: 0.0010
# Epoch 338/500
# 1/1 [==============================] - 0s 290ms/step - loss: 0.1386 - val_loss: 0.1329 - lr: 0.0010
# Epoch 339/500
# 1/1 [==============================] - 0s 289ms/step - loss: 0.1329 - val_loss: 0.1363 - lr: 0.0010
# Epoch 340/500
# 1/1 [==============================] - 0s 317ms/step - loss: 0.1363 - val_loss: 0.1361 - lr: 0.0010
# Epoch 341/500
# 1/1 [==============================] - 0s 282ms/step - loss: 0.1361 - val_loss: 0.1307 - lr: 0.0010
# Epoch 342/500
# 1/1 [==============================] - 0s 296ms/step - loss: 0.1307 - val_loss: 0.1296 - lr: 0.0010
# Epoch 343/500
# 1/1 [==============================] - 0s 298ms/step - loss: 0.1296 - val_loss: 0.1316 - lr: 0.0010
# Epoch 344/500
# 1/1 [==============================] - 0s 281ms/step - loss: 0.1316 - val_loss: 0.1297 - lr: 0.0010
# Epoch 345/500
# 1/1 [==============================] - 0s 286ms/step - loss: 0.1297 - val_loss: 0.1259 - lr: 0.0010
# Epoch 346/500
# 1/1 [==============================] - 0s 292ms/step - loss: 0.1259 - val_loss: 0.1259 - lr: 0.0010
# Epoch 347/500
# 1/1 [==============================] - 0s 294ms/step - loss: 0.1259 - val_loss: 0.1269 - lr: 0.0010
# Epoch 348/500
# 1/1 [==============================] - 0s 289ms/step - loss: 0.1269 - val_loss: 0.1245 - lr: 0.0010
# Epoch 349/500
# 1/1 [==============================] - 0s 296ms/step - loss: 0.1245 - val_loss: 0.1219 - lr: 0.0010
# Epoch 350/500
# 1/1 [==============================] - 0s 336ms/step - loss: 0.1219 - val_loss: 0.1223 - lr: 0.0010
# Epoch 351/500
# 1/1 [==============================] - 0s 294ms/step - loss: 0.1223 - val_loss: 0.1220 - lr: 0.0010
# Epoch 352/500
# 1/1 [==============================] - 0s 330ms/step - loss: 0.1220 - val_loss: 0.1204 - lr: 0.0010
# Epoch 353/500
# 1/1 [==============================] - 0s 302ms/step - loss: 0.1204 - val_loss: 0.1184 - lr: 0.0010
# Epoch 354/500
# 1/1 [==============================] - 0s 292ms/step - loss: 0.1184 - val_loss: 0.1181 - lr: 0.0010
# Epoch 355/500
# 1/1 [==============================] - 0s 286ms/step - loss: 0.1181 - val_loss: 0.1182 - lr: 0.0010
# Epoch 356/500
# 1/1 [==============================] - 0s 282ms/step - loss: 0.1182 - val_loss: 0.1170 - lr: 0.0010
# Epoch 357/500
# 1/1 [==============================] - 0s 294ms/step - loss: 0.1170 - val_loss: 0.1154 - lr: 0.0010
# Epoch 358/500
# 1/1 [==============================] - 0s 289ms/step - loss: 0.1154 - val_loss: 0.1144 - lr: 0.0010
# Epoch 359/500
# 1/1 [==============================] - 0s 293ms/step - loss: 0.1144 - val_loss: 0.1142 - lr: 0.0010
# Epoch 360/500
# 1/1 [==============================] - 0s 335ms/step - loss: 0.1142 - val_loss: 0.1138 - lr: 0.0010
# Epoch 361/500
# 1/1 [==============================] - 0s 284ms/step - loss: 0.1138 - val_loss: 0.1129 - lr: 0.0010
# Epoch 362/500
# 1/1 [==============================] - 0s 292ms/step - loss: 0.1129 - val_loss: 0.1116 - lr: 0.0010
# Epoch 363/500
# 1/1 [==============================] - 0s 291ms/step - loss: 0.1116 - val_loss: 0.1105 - lr: 0.0010
# Epoch 364/500
# 1/1 [==============================] - 0s 296ms/step - loss: 0.1105 - val_loss: 0.1100 - lr: 0.0010
# Epoch 365/500
# 1/1 [==============================] - 0s 286ms/step - loss: 0.1100 - val_loss: 0.1095 - lr: 0.0010
# Epoch 366/500
# 1/1 [==============================] - 0s 300ms/step - loss: 0.1095 - val_loss: 0.1093 - lr: 0.0010
# Epoch 367/500
# 1/1 [==============================] - 0s 302ms/step - loss: 0.1093 - val_loss: 0.1088 - lr: 0.0010
# Epoch 368/500
# 1/1 [==============================] - 0s 288ms/step - loss: 0.1088 - val_loss: 0.1082 - lr: 0.0010
# Epoch 369/500
# 1/1 [==============================] - 0s 290ms/step - loss: 0.1082 - val_loss: 0.1076 - lr: 0.0010
# Epoch 370/500
# 1/1 [==============================] - 0s 384ms/step - loss: 0.1076 - val_loss: 0.1071 - lr: 0.0010
# Epoch 371/500
# 1/1 [==============================] - 0s 287ms/step - loss: 0.1071 - val_loss: 0.1067 - lr: 0.0010
# Epoch 372/500
# 1/1 [==============================] - 0s 288ms/step - loss: 0.1067 - val_loss: 0.1068 - lr: 0.0010
# Epoch 373/500
# 1/1 [==============================] - 0s 289ms/step - loss: 0.1068 - val_loss: 0.1081 - lr: 0.0010
# Epoch 374/500
# 1/1 [==============================] - 0s 283ms/step - loss: 0.1081 - val_loss: 0.1124 - lr: 0.0010
# Epoch 375/500
# 1/1 [==============================] - 0s 285ms/step - loss: 0.1124 - val_loss: 0.1350 - lr: 0.0010
# Epoch 376/500
# 1/1 [==============================] - 0s 284ms/step - loss: 0.1350 - val_loss: 0.2638 - lr: 0.0010
# Epoch 377/500
# 1/1 [==============================] - 0s 288ms/step - loss: 0.2638 - val_loss: 0.3299 - lr: 0.0010
# Epoch 378/500
# 1/1 [==============================] - 0s 294ms/step - loss: 0.3299 - val_loss: 0.1909 - lr: 0.0010
# Epoch 379/500
# 1/1 [==============================] - 0s 281ms/step - loss: 0.1909 - val_loss: 0.2458 - lr: 0.0010
# Epoch 380/500
# 1/1 [==============================] - 0s 324ms/step - loss: 0.2458 - val_loss: 0.1993 - lr: 0.0010
# Epoch 381/500
# 1/1 [==============================] - 0s 285ms/step - loss: 0.1993 - val_loss: 0.1935 - lr: 0.0010
# Epoch 382/500
# 1/1 [==============================] - 0s 279ms/step - loss: 0.1935 - val_loss: 0.1971 - lr: 0.0010
# Epoch 383/500
# 1/1 [==============================] - 0s 286ms/step - loss: 0.1971 - val_loss: 0.2253 - lr: 0.0010
# Epoch 384/500
# 1/1 [==============================] - 0s 284ms/step - loss: 0.2253 - val_loss: 0.2138 - lr: 0.0010
# Epoch 385/500
# 1/1 [==============================] - 0s 287ms/step - loss: 0.2138 - val_loss: 0.3149 - lr: 0.0010
# Epoch 386/500
# 1/1 [==============================] - 0s 292ms/step - loss: 0.3149 - val_loss: 0.4593 - lr: 0.0010
# Epoch 387/500
# 1/1 [==============================] - 0s 287ms/step - loss: 0.4593 - val_loss: 0.2378 - lr: 0.0010
# Epoch 388/500
# 1/1 [==============================] - 0s 282ms/step - loss: 0.2378 - val_loss: 0.4407 - lr: 0.0010
# Epoch 389/500
# 1/1 [==============================] - 0s 281ms/step - loss: 0.4407 - val_loss: 0.2410 - lr: 0.0010
# Epoch 390/500
# 1/1 [==============================] - 0s 310ms/step - loss: 0.2410 - val_loss: 0.3322 - lr: 0.0010
# Epoch 391/500
# 1/1 [==============================] - 0s 313ms/step - loss: 0.3322 - val_loss: 0.2257 - lr: 0.0010
# 1/1 [==============================] - 2s 2s/step
# Validation RMSE: 0.3266987916252384

# %%
import matplotlib.pyplot as plt

# Assuming that one_lifeline is your data reshaped correctly for the model input
# Example: one_lifeline = np.random.rand(1, 376, 1)  # Use your actual reshaped data here

# Predict the reconstruction for the lifeline
reconstructed = autoencoder.predict(train_data)
lifeline = 5
feature = 6 

# Flatten the arrays to be able to plot them since they contain a single feature
scaled_series = train_data[lifeline,:,feature]
reconstructed_series = reconstructed[lifeline,:,feature]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(scaled_series, label='Original Data', color='blue')
plt.plot(reconstructed_series, label='Reconstructed Data', color='red', linestyle='--')
plt.title('Lifeline 1 for Single Feature')
plt.xlabel('Timepoint')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 111ms/step

# %%
from tensorflow.keras.models import Model

# Assuming 'encoded' is the output of your last encoder layer and 'inputs' is your input layer
latent_model = Model(inputs, latent_space)
latent_representations = latent_model.predict(train_data)
# Out:
# 1/1 [==============================] - 1s 921ms/step

# %%
import pandas as pd

# Convert the latent representations to a DataFrame
latent_df = pd.DataFrame(latent_representations)

# Specify your desired Excel file path
excel_file_path = 'D:/Desktop/Work/Multiple Lifelines/latent_representations_14_lifelines.csv'

# Save the DataFrame to an Excel file
latent_df.to_csv(excel_file_path, index=False)

print(f"Latent representations saved to {excel_file_path}")
# Out:
# Latent representations saved to D:/Desktop/Work/Multiple Lifelines/latent_representations_14_lifelines.csv

# %%
import optuna
from tensorflow.keras.layers import Input, LSTM, RepeatVector, Dense, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.initializers import glorot_uniform, he_normal
from sklearn.model_selection import train_test_split

# Assuming 'normalized_data' is defined elsewhere in your script
# normalized_data = ...

# Define the objective function to optimize
def objective(trial):
    # Hyperparameter setting
    lstm_units = trial.suggest_categorical('lstm_units', [200, 300, 350, 400])
    lstm_units_layer2 = trial.suggest_categorical('lstm_units_layer2', [200, 250, 275, 300])  # Key name changed
    dense_units = trial.suggest_categorical('dense_units', [50, 100, 150, 200])
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-2)
    batch_size = trial.suggest_categorical('batch_size', [16, 32, 64])

    # Split the data
    train_data, val_data = train_test_split(normalized_data, test_size=0.2, random_state=42)

    # Define the input layer with the shape (timesteps, features)
    input_shape = (train_data.shape[1], train_data.shape[2])
    inputs = Input(shape=input_shape)

    # Encoder layers with glorot_uniform initializer
    encoded = LSTM(lstm_units, activation='tanh', return_sequences=True,
                   kernel_initializer=glorot_uniform(seed=0))(inputs)
    encoded = LSTM(lstm_units_layer2, activation='tanh', return_sequences=False,
                   kernel_initializer=glorot_uniform(seed=0))(encoded)

    # Latent space with he_normal initializer
    latent_space = Dense(dense_units, activation='tanh',
                         kernel_initializer=he_normal(seed=0))(encoded)

    # Decoder layers, repeat the latent space at each timestep
    decoded = RepeatVector(input_shape[0])(latent_space)
    decoded = LSTM(lstm_units_layer2, activation='tanh', return_sequences=True,
                   kernel_initializer=glorot_uniform(seed=0))(decoded)
    decoded = LSTM(lstm_units, activation='tanh', return_sequences=True,
                   kernel_initializer=glorot_uniform(seed=0))(decoded)

    # Output layer, reconstruct the original input
    outputs = TimeDistributed(Dense(input_shape[1]))(decoded)

    # Create the autoencoder model
    autoencoder = Model(inputs, outputs)
    autoencoder.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')

    # Early stopping and learning rate reduction
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)

    # Model training
    history = autoencoder.fit(train_data, train_data, epochs=700, batch_size=batch_size,
                              validation_data=(val_data, val_data), callbacks=[early_stop, reduce_lr], verbose=0)

    # Retrieve the best score
    best_score = min(history.history['val_loss'])
    return best_score

# Create a study object and specify the direction is 'minimize'.
study = optuna.create_study(direction='minimize')

# Optimize the study, the objective function is passed in as the first argument.
study.optimize(objective, n_trials=10)  # You can change n_trials to the number of iterations you want to perform

# Print the result
print(study.best_params)
# Out:
# [I 2024-02-21 13:53:44,135] A new study created in memory with name: no-name-9527dc86-4666-4c77-bade-617d26e31c4c
# C:\Users\elysi\AppData\Local\Temp\ipykernel_18092\577897805.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-2)
# [I 2024-02-21 13:53:58,746] Trial 0 finished with value: 0.9940025210380554 and parameters: {'lstm_units': 200, 'lstm_units_layer2': 275, 'dense_units': 200, 'learning_rate': 4.57064882981988e-05, 'batch_size': 32}. Best is trial 0 with value: 0.9940025210380554.
# [I 2024-02-21 13:54:25,044] Trial 1 finished with value: 0.807985782623291 and parameters: {'lstm_units': 400, 'lstm_units_layer2': 250, 'dense_units': 100, 'learning_rate': 0.00021939476012720676, 'batch_size': 64}. Best is trial 1 with value: 0.807985782623291.
# [I 2024-02-21 13:56:37,712] Trial 2 finished with value: 0.8349940180778503 and parameters: {'lstm_units': 300, 'lstm_units_layer2': 200, 'dense_units': 100, 'learning_rate': 2.8378376569357638e-05, 'batch_size': 64}. Best is trial 1 with value: 0.807985782623291.
# [I 2024-02-21 13:58:03,138] Trial 3 finished with value: 0.8162214159965515 and parameters: {'lstm_units': 200, 'lstm_units_layer2': 300, 'dense_units': 50, 'learning_rate': 7.930915659563366e-05, 'batch_size': 64}. Best is trial 1 with value: 0.807985782623291.
# [I 2024-02-21 13:58:31,218] Trial 4 finished with value: 1.007218599319458 and parameters: {'lstm_units': 350, 'lstm_units_layer2': 300, 'dense_units': 200, 'learning_rate': 0.008962161720546912, 'batch_size': 64}. Best is trial 1 with value: 0.807985782623291.
# [I 2024-02-21 13:58:47,896] Trial 5 finished with value: 0.9931829571723938 and parameters: {'lstm_units': 200, 'lstm_units_layer2': 300, 'dense_units': 150, 'learning_rate': 4.1998993888026845e-05, 'batch_size': 64}. Best is trial 1 with value: 0.807985782623291.
# [I 2024-02-21 13:59:33,748] Trial 6 finished with value: 0.7509554028511047 and parameters: {'lstm_units': 400, 'lstm_units_layer2': 275, 'dense_units': 150, 'learning_rate': 0.0018106563859353615, 'batch_size': 32}. Best is trial 6 with value: 0.7509554028511047.
# [I 2024-02-21 13:59:50,291] Trial 7 finished with value: 0.9939162135124207 and parameters: {'lstm_units': 300, 'lstm_units_layer2': 200, 'dense_units': 200, 'learning_rate': 2.0250019301971043e-05, 'batch_size': 16}. Best is trial 6 with value: 0.7509554028511047.
# [I 2024-02-21 14:00:11,924] Trial 8 finished with value: 0.7516587376594543 and parameters: {'lstm_units': 200, 'lstm_units_layer2': 250, 'dense_units': 50, 'learning_rate': 0.001847793858878538, 'batch_size': 32}. Best is trial 6 with value: 0.7509554028511047.
# [I 2024-02-21 14:00:49,292] Trial 9 finished with value: 0.7160378098487854 and parameters: {'lstm_units': 400, 'lstm_units_layer2': 300, 'dense_units': 100, 'learning_rate': 0.00040225479094866155, 'batch_size': 16}. Best is trial 9 with value: 0.7160378098487854.
# {'lstm_units': 400, 'lstm_units_layer2': 300, 'dense_units': 100, 'learning_rate': 0.00040225479094866155, 'batch_size': 16}

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, RepeatVector, Dense, TimeDistributed
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# Optimized hyperparameters
lstm_units = study.best_params['lstm_units'] # Optimized LSTM units for both encoder and decoder
lstm_units_layer2 = study.best_params['lstm_units_layer2']
dense_units = study.best_params['dense_units'] # Optimized Dense units for latent representation
learning_rate = study.best_params['learning_rate']  # Optimized learning rate
batch_size = study.best_params['batch_size']  # Optimized batch size

# Split the data
train_data, val_data = train_test_split(normalized_data, test_size=0.2, random_state=42)

# Define the input layer with the shape (timesteps, features)
input_shape = (train_data.shape[1], train_data.shape[2])
inputs = Input(shape=input_shape)

# Encoder layers with glorot_uniform initializer
encoded = LSTM(lstm_units, activation='tanh', return_sequences=True,
                   kernel_initializer=glorot_uniform(seed=0))(inputs)
encoded = LSTM(lstm_units_layer2, activation='tanh', return_sequences=False,
                   kernel_initializer=glorot_uniform(seed=0))(encoded)

# Latent space with he_normal initializer
latent_space = Dense(dense_units, activation='tanh',
                         kernel_initializer=he_normal(seed=0))(encoded)

# Decoder layers, repeat the latent space at each timestep
decoded = RepeatVector(input_shape[0])(latent_space)
decoded = LSTM(lstm_units_layer2, activation='tanh', return_sequences=True,
                   kernel_initializer=glorot_uniform(seed=0))(decoded)
decoded = LSTM(lstm_units, activation='tanh', return_sequences=True,
                   kernel_initializer=glorot_uniform(seed=0))(decoded)

# Output layer, reconstruct the original input
outputs = TimeDistributed(Dense(input_shape[1]))(decoded)

# Create the autoencoder model
autoencoder = Model(inputs, outputs)
autoencoder.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')

# Callbacks for training
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.00001)
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = autoencoder.fit(train_data, train_data, epochs=400, batch_size=batch_size,
                              validation_data=(val_data, val_data), callbacks=[early_stop, reduce_lr], verbose=0)
# Predict on the validation set
val_predictions = autoencoder.predict(val_data)

# Compute mean squared error on the validation set
mean_squared_error = np.mean(np.square(val_data - val_predictions))

# Compute root mean squared error (RMSE)
reconstruction_loss = np.sqrt(mean_squared_error)
print(f"Validation RMSE: {reconstruction_loss}")
# Out:
# 1/1 [==============================] - 1s 1s/step
# Validation RMSE: 0.8765563444114308

# %%
import matplotlib.pyplot as plt

# Choose a specific lifeline and reaction for plotting
lifeline_index = 12  # Index for lifeline 0 
reaction_index = 6 # Reaction index, biomass reaction

# Predict the reconstruction for the lifeline
reconstructed = autoencoder.predict(normalized_data)

# Extract series for plotting
scaled_series = normalized_data[lifeline_index, :, reaction_index]
reconstructed_series = reconstructed[lifeline_index, :, reaction_index]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(scaled_series, label='Original Data', color='blue')
plt.plot(reconstructed_series, label='Reconstructed Data', color='red', linestyle='--')
plt.title(f'Lifeline 1 for Reaction {reaction_index}')
plt.xlabel('Timepoint')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 125ms/step

# %%
from tensorflow.keras.models import Model

# Assuming 'encoded' is the output of your last encoder layer and 'inputs' is your input layer
latent_model = Model(inputs, latent_space)
latent_representations = latent_model.predict(train_data)

# %%
import pandas as pd

# Convert the latent representations to a DataFrame
latent_df = pd.DataFrame(latent_representations)

# Specify your desired Excel file path
excel_file_path = '/mnt/data/latent_representations_tuned.xlsx'

# Save the DataFrame to an Excel file
latent_df.to_excel(excel_file_path, index=False)

print(f"Latent representations saved to {excel_file_path}")

# %% [markdown]
# # Training 100 Lifelines

# %%
import os
import pandas as pd
import numpy as np

folder_path = '100_dFBA_Lifelines'
file_names = sorted(os.listdir(folder_path))

expected_timepoints = 376 # reduced timepoints by 10 for faster runs, just temporary 

for file_name in file_names:
    file_path = os.path.join(folder_path, file_name)
    lifeline_df = pd.read_csv(file_path, sep="\t", index_col=0)

    # Select every 10th row and ensure there are exactly 376 timepoints
    reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
    reduced_df.to_csv(file_path, sep="\t")

data_list = []
filtered_reactions = None

for file_name in file_names:
    file_path = os.path.join(folder_path, file_name)
    lifeline_df = pd.read_csv(file_path, sep="\t", index_col=0)

    if filtered_reactions is None:
        non_constant_fluxes_df = lifeline_df.loc[:, (lifeline_df != lifeline_df.iloc[0]).any()]
        unique_reactions_fluxes_df = non_constant_fluxes_df.loc[:, ~non_constant_fluxes_df.columns.duplicated()]
        filtered_reactions = unique_reactions_fluxes_df.columns

    filtered_lifeline_df = lifeline_df[filtered_reactions]

    if filtered_lifeline_df.shape != (expected_timepoints, len(filtered_reactions)):
        print(f"Shape mismatch for file: {file_name}. Expected ({expected_timepoints}, {len(filtered_reactions)}) but got {filtered_lifeline_df.shape}")

    data_list.append(filtered_lifeline_df.to_numpy())

data_3d = np.stack(data_list, axis=1)
print("Shape of the Big Matrix:", data_3d.shape)
# Out:
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# Shape mismatch for file: lifeline_0_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_100_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_10_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_11_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_12_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_13_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_14_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_15_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_16_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_17_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_18_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_19_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_1_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_20_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_21_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_22_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_23_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_24_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_25_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_26_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_27_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_28_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_29_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_2_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_30_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_31_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_32_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_33_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_34_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_35_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_36_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_37_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_38_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_39_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_3_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_40_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_41_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_42_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_43_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_44_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_45_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_46_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_47_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_48_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_49_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_4_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_50_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_51_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_52_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_53_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_54_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_55_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_56_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_57_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_58_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_59_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_5_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_60_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_61_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_62_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_63_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_64_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_65_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_66_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_67_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_68_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_69_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_6_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_70_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_71_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_72_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_73_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_74_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_75_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_76_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_77_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_78_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_79_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_7_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_80_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_81_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_82_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_83_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_84_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_85_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_86_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_87_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_88_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_89_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_8_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_90_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_91_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_92_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_93_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_94_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_95_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_96_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_97_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_98_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_99_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_9_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape of the Big Matrix: (38, 101, 48)

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# Assuming data_3d is original data with shape (n_timesteps, n_samples, n_features)
# Example: n_timesteps = 376, n_samples = 14, n_features = 48

n_timesteps, n_samples, n_features = data_3d.shape

# Initialize a StandardScaler for each feature for each sample
scalers = [[StandardScaler() for _ in range(n_features)] for _ in range(n_samples)]

# Normalized data will have the same shape as data_3d initially
normalized_data = np.empty_like(data_3d, dtype=float)

# Apply the scalers to each feature for each sample across all timesteps
for sample_index in range(n_samples):
    for feature_index in range(n_features):
        # Extract the feature data for the current sample
        feature_data = data_3d[:, sample_index, feature_index].reshape(-1, 1)
        
        # Fit and transform the data using the corresponding scaler
        normalized_feature_data = scalers[sample_index][feature_index].fit_transform(feature_data)
        
        # Assign the normalized data back to its position in the normalized_data array
        normalized_data[:, sample_index, feature_index] = normalized_feature_data.flatten()

# Transpose normalized_data to have the shape (n_samples, n_timesteps, n_features)
normalized_data = np.transpose(normalized_data, (1, 0, 2))

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, RepeatVector, TimeDistributed
from tensorflow.keras.initializers import glorot_uniform, he_normal
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# Assuming five_lifeline is a 3D array with the shape (1, 376, 48)
train_data = normalized_data
val_data = train_data  # Using the same data for validation as a placeholder

# Define the input layer with the shape (timesteps, features)
input_shape = (train_data.shape[1], train_data.shape[2])
inputs = Input(shape=input_shape)

# Encoder layers with glorot_uniform initializer
encoded = LSTM(600, activation='tanh', return_sequences=True,
               kernel_initializer=glorot_uniform(seed=0))(inputs)
encoded = LSTM(500, activation='tanh', return_sequences=True,
               kernel_initializer=glorot_uniform(seed=0))(encoded)
encoded = LSTM(450, activation='tanh', return_sequences=False,
               kernel_initializer=glorot_uniform(seed=0))(encoded)
# Latent space with he_normal initializer
latent_space = Dense(100, activation='tanh',
                     kernel_initializer=he_normal(seed=0))(encoded)

# Decoder layers, repeat the latent space at each timestep
decoded = RepeatVector(input_shape[0])(latent_space)
decoded = LSTM(450, activation='tanh', return_sequences=True,
               kernel_initializer=glorot_uniform(seed=0))(decoded)
decoded = LSTM(500, activation='tanh', return_sequences=True,
               kernel_initializer=glorot_uniform(seed=0))(decoded)
decoded = LSTM(600, activation='tanh', return_sequences=True,
               kernel_initializer=glorot_uniform(seed=0))(decoded)

# Output layer, reconstruct the original input
outputs = TimeDistributed(Dense(input_shape[1]))(decoded)

# Create the autoencoder model
autoencoder = Model(inputs, outputs)
autoencoder.compile(optimizer='adam', loss='mse')

# Summary of the model
autoencoder.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 38, 48)]          0
#
#  lstm_24 (LSTM)              (None, 38, 600)           1557600
#
#  lstm_25 (LSTM)              (None, 38, 500)           2202000
#
#  lstm_26 (LSTM)              (None, 450)               1711800
#
#  dense_8 (Dense)             (None, 100)               45100
#
#  repeat_vector_4 (RepeatVec  (None, 38, 100)           0
#  tor)
#
#  lstm_27 (LSTM)              (None, 38, 450)           991800
#
#  lstm_28 (LSTM)              (None, 38, 500)           1902000
#
#  lstm_29 (LSTM)              (None, 38, 600)           2642400
#
#  time_distributed_4 (TimeDi  (None, 38, 48)            28848
#  stributed)
#
# =================================================================
# Total params: 11081548 (42.27 MB)
# Trainable params: 11081548 (42.27 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Callbacks
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=20, min_lr=0.00001)
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Fit the model
history = autoencoder.fit(
    train_data,
    train_data,
    epochs = 500,
    batch_size=32,  # Adjust the batch size if necessary
    validation_data=(val_data, val_data),
    callbacks=[reduce_lr, early_stop]
)

# Predict on the validation set
val_predictions = autoencoder.predict(val_data)

# Compute mean squared error on the validation set
mean_squared_error = np.mean(np.square(val_data - val_predictions))

# Compute root mean squared error (RMSE)
reconstruction_loss = np.sqrt(mean_squared_error)
print(f"Validation RMSE: {reconstruction_loss}")
# Out:
# Epoch 1/500
# 4/4 [==============================] - 27s 5s/step - loss: 1.0911 - val_loss: 0.9897 - lr: 0.0010
# Epoch 2/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.9860 - val_loss: 0.9639 - lr: 0.0010
# Epoch 3/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.9559 - val_loss: 0.9308 - lr: 0.0010
# Epoch 4/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.9765 - val_loss: 0.9633 - lr: 0.0010
# Epoch 5/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.9444 - val_loss: 0.9380 - lr: 0.0010
# Epoch 6/500
# 4/4 [==============================] - 16s 4s/step - loss: 0.9285 - val_loss: 0.9048 - lr: 0.0010
# Epoch 7/500
# 4/4 [==============================] - 15s 4s/step - loss: 0.8964 - val_loss: 0.8887 - lr: 0.0010
# Epoch 8/500
# 4/4 [==============================] - 15s 4s/step - loss: 0.8920 - val_loss: 0.8622 - lr: 0.0010
# Epoch 9/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.8532 - val_loss: 0.8293 - lr: 0.0010
# Epoch 10/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.8526 - val_loss: 0.8114 - lr: 0.0010
# Epoch 11/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.8210 - val_loss: 0.8037 - lr: 0.0010
# Epoch 12/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.7989 - val_loss: 0.8373 - lr: 0.0010
# Epoch 13/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.8326 - val_loss: 0.8202 - lr: 0.0010
# Epoch 14/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.8100 - val_loss: 0.8337 - lr: 0.0010
# Epoch 15/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.8191 - val_loss: 0.8251 - lr: 0.0010
# Epoch 16/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.8131 - val_loss: 0.7999 - lr: 0.0010
# Epoch 17/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.7995 - val_loss: 0.7813 - lr: 0.0010
# Epoch 18/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.7747 - val_loss: 0.8598 - lr: 0.0010
# Epoch 19/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.8547 - val_loss: 0.8038 - lr: 0.0010
# Epoch 20/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.8063 - val_loss: 0.9324 - lr: 0.0010
# Epoch 21/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.8666 - val_loss: 0.8677 - lr: 0.0010
# Epoch 22/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.8460 - val_loss: 0.8188 - lr: 0.0010
# Epoch 23/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.8025 - val_loss: 0.9336 - lr: 0.0010
# Epoch 24/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.8527 - val_loss: 0.8015 - lr: 0.0010
# Epoch 25/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.7990 - val_loss: 0.7786 - lr: 0.0010
# Epoch 26/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.7640 - val_loss: 0.7527 - lr: 0.0010
# Epoch 27/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.7493 - val_loss: 0.8094 - lr: 0.0010
# Epoch 28/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.7796 - val_loss: 0.7392 - lr: 0.0010
# Epoch 29/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.7448 - val_loss: 0.7814 - lr: 0.0010
# Epoch 30/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.7528 - val_loss: 0.7260 - lr: 0.0010
# Epoch 31/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.7411 - val_loss: 0.7096 - lr: 0.0010
# Epoch 32/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.7135 - val_loss: 0.6998 - lr: 0.0010
# Epoch 33/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.7021 - val_loss: 0.7405 - lr: 0.0010
# Epoch 34/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.7095 - val_loss: 0.7046 - lr: 0.0010
# Epoch 35/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.7043 - val_loss: 0.7055 - lr: 0.0010
# Epoch 36/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6923 - val_loss: 0.6930 - lr: 0.0010
# Epoch 37/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6936 - val_loss: 0.6863 - lr: 0.0010
# Epoch 38/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6867 - val_loss: 0.6669 - lr: 0.0010
# Epoch 39/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6684 - val_loss: 0.6570 - lr: 0.0010
# Epoch 40/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6583 - val_loss: 0.6381 - lr: 0.0010
# Epoch 41/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6422 - val_loss: 0.6447 - lr: 0.0010
# Epoch 42/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6427 - val_loss: 0.6748 - lr: 0.0010
# Epoch 43/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6991 - val_loss: 0.6865 - lr: 0.0010
# Epoch 44/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6900 - val_loss: 0.6586 - lr: 0.0010
# Epoch 45/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6597 - val_loss: 0.6409 - lr: 0.0010
# Epoch 46/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6506 - val_loss: 0.6382 - lr: 0.0010
# Epoch 47/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6443 - val_loss: 0.6638 - lr: 0.0010
# Epoch 48/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6683 - val_loss: 0.6788 - lr: 0.0010
# Epoch 49/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6551 - val_loss: 0.6305 - lr: 0.0010
# Epoch 50/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6367 - val_loss: 0.6421 - lr: 0.0010
# Epoch 51/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6264 - val_loss: 0.6142 - lr: 0.0010
# Epoch 52/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6302 - val_loss: 0.6240 - lr: 0.0010
# Epoch 53/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6296 - val_loss: 0.6236 - lr: 0.0010
# Epoch 54/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6238 - val_loss: 0.6242 - lr: 0.0010
# Epoch 55/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6268 - val_loss: 0.6488 - lr: 0.0010
# Epoch 56/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6448 - val_loss: 0.6655 - lr: 0.0010
# Epoch 57/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.6924 - val_loss: 0.6389 - lr: 0.0010
# Epoch 58/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.6453 - val_loss: 0.6322 - lr: 0.0010
# Epoch 59/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6346 - val_loss: 0.6223 - lr: 0.0010
# Epoch 60/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6244 - val_loss: 0.6090 - lr: 0.0010
# Epoch 61/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.6130 - val_loss: 0.6044 - lr: 0.0010
# Epoch 62/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6149 - val_loss: 0.6053 - lr: 0.0010
# Epoch 63/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6026 - val_loss: 0.6781 - lr: 0.0010
# Epoch 64/500
# 4/4 [==============================] - 14s 3s/step - loss: 0.6490 - val_loss: 0.5956 - lr: 0.0010
# Epoch 65/500
# 4/4 [==============================] - 13s 3s/step - loss: 0.6330 - val_loss: 0.6664 - lr: 0.0010
# Epoch 66/500
# 4/4 [==============================] - 15s 4s/step - loss: 0.6530 - val_loss: 0.6246 - lr: 0.0010
# Epoch 67/500
# 4/4 [==============================] - 15s 4s/step - loss: 0.6119 - val_loss: 0.5958 - lr: 0.0010
# Epoch 68/500
# 4/4 [==============================] - 15s 4s/step - loss: 0.6173 - val_loss: 0.5919 - lr: 0.0010
# Epoch 69/500
# 4/4 [==============================] - 15s 4s/step - loss: 0.5959 - val_loss: 0.5799 - lr: 0.0010
# Epoch 70/500
# 4/4 [==============================] - 15s 4s/step - loss: 0.5884 - val_loss: 0.5889 - lr: 0.0010
# Epoch 71/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5933 - val_loss: 0.5822 - lr: 0.0010
# Epoch 72/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5786 - val_loss: 0.5618 - lr: 0.0010
# Epoch 73/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5677 - val_loss: 0.5700 - lr: 0.0010
# Epoch 74/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5730 - val_loss: 0.5877 - lr: 0.0010
# Epoch 75/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5771 - val_loss: 0.5581 - lr: 0.0010
# Epoch 76/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5694 - val_loss: 0.5899 - lr: 0.0010
# Epoch 77/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.6001 - val_loss: 0.6326 - lr: 0.0010
# Epoch 78/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5946 - val_loss: 0.6381 - lr: 0.0010
# Epoch 79/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.6015 - val_loss: 0.6272 - lr: 0.0010
# Epoch 80/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.6058 - val_loss: 0.6064 - lr: 0.0010
# Epoch 81/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.5936 - val_loss: 0.5857 - lr: 0.0010
# Epoch 82/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5771 - val_loss: 0.5632 - lr: 0.0010
# Epoch 83/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5781 - val_loss: 0.5575 - lr: 0.0010
# Epoch 84/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.5663 - val_loss: 0.5670 - lr: 0.0010
# Epoch 85/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5658 - val_loss: 0.5440 - lr: 0.0010
# Epoch 86/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5501 - val_loss: 0.5282 - lr: 0.0010
# Epoch 87/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5351 - val_loss: 0.5263 - lr: 0.0010
# Epoch 88/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5289 - val_loss: 0.5200 - lr: 0.0010
# Epoch 89/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.5220 - val_loss: 0.5151 - lr: 0.0010
# Epoch 90/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5170 - val_loss: 0.5245 - lr: 0.0010
# Epoch 91/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5335 - val_loss: 0.5162 - lr: 0.0010
# Epoch 92/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5315 - val_loss: 0.5509 - lr: 0.0010
# Epoch 93/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5686 - val_loss: 0.5406 - lr: 0.0010
# Epoch 94/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5505 - val_loss: 0.5576 - lr: 0.0010
# Epoch 95/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.5534 - val_loss: 0.5417 - lr: 0.0010
# Epoch 96/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5466 - val_loss: 0.5433 - lr: 0.0010
# Epoch 97/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5454 - val_loss: 0.5343 - lr: 0.0010
# Epoch 98/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.5324 - val_loss: 0.5509 - lr: 0.0010
# Epoch 99/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5438 - val_loss: 0.5163 - lr: 0.0010
# Epoch 100/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5284 - val_loss: 0.5339 - lr: 0.0010
# Epoch 101/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5473 - val_loss: 0.5368 - lr: 0.0010
# Epoch 102/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5248 - val_loss: 0.5198 - lr: 0.0010
# Epoch 103/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.5206 - val_loss: 0.5099 - lr: 0.0010
# Epoch 104/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.5169 - val_loss: 0.5222 - lr: 0.0010
# Epoch 105/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5360 - val_loss: 0.5095 - lr: 0.0010
# Epoch 106/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5130 - val_loss: 0.5161 - lr: 0.0010
# Epoch 107/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5089 - val_loss: 0.5096 - lr: 0.0010
# Epoch 108/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5043 - val_loss: 0.5129 - lr: 0.0010
# Epoch 109/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.5192 - val_loss: 0.4898 - lr: 0.0010
# Epoch 110/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.4993 - val_loss: 0.5089 - lr: 0.0010
# Epoch 111/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.4954 - val_loss: 0.5112 - lr: 0.0010
# Epoch 112/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.5184 - val_loss: 0.5046 - lr: 0.0010
# Epoch 113/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.5241 - val_loss: 0.4873 - lr: 0.0010
# Epoch 114/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.4924 - val_loss: 0.5240 - lr: 0.0010
# Epoch 115/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.5145 - val_loss: 0.5239 - lr: 0.0010
# Epoch 116/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.5573 - val_loss: 0.5880 - lr: 0.0010
# Epoch 117/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.5784 - val_loss: 0.5570 - lr: 0.0010
# Epoch 118/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.5566 - val_loss: 0.5347 - lr: 0.0010
# Epoch 119/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.5590 - val_loss: 0.5495 - lr: 0.0010
# Epoch 120/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.5512 - val_loss: 0.5416 - lr: 0.0010
# Epoch 121/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.5431 - val_loss: 0.5229 - lr: 0.0010
# Epoch 122/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.5294 - val_loss: 0.5306 - lr: 0.0010
# Epoch 123/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5419 - val_loss: 0.5197 - lr: 0.0010
# Epoch 124/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5195 - val_loss: 0.5119 - lr: 0.0010
# Epoch 125/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5090 - val_loss: 0.4988 - lr: 0.0010
# Epoch 126/500
# 4/4 [==============================] - 15s 4s/step - loss: 0.4961 - val_loss: 0.4751 - lr: 0.0010
# Epoch 127/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.4868 - val_loss: 0.4980 - lr: 0.0010
# Epoch 128/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.4977 - val_loss: 0.4994 - lr: 0.0010
# Epoch 129/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5208 - val_loss: 0.4999 - lr: 0.0010
# Epoch 130/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5012 - val_loss: 0.5427 - lr: 0.0010
# Epoch 131/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5203 - val_loss: 0.4992 - lr: 0.0010
# Epoch 132/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5620 - val_loss: 0.5478 - lr: 0.0010
# Epoch 133/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5431 - val_loss: 0.5138 - lr: 0.0010
# Epoch 134/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5226 - val_loss: 0.4981 - lr: 0.0010
# Epoch 135/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5080 - val_loss: 0.5044 - lr: 0.0010
# Epoch 136/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.5021 - val_loss: 0.4838 - lr: 0.0010
# Epoch 137/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.4991 - val_loss: 0.4844 - lr: 0.0010
# Epoch 138/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.4979 - val_loss: 0.5204 - lr: 0.0010
# Epoch 139/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5071 - val_loss: 0.4830 - lr: 0.0010
# Epoch 140/500
# 4/4 [==============================] - 13s 4s/step - loss: 0.4837 - val_loss: 0.4768 - lr: 0.0010
# Epoch 141/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.4904 - val_loss: 0.4805 - lr: 0.0010
# Epoch 142/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.4773 - val_loss: 0.4642 - lr: 0.0010
# Epoch 143/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.4815 - val_loss: 0.4487 - lr: 0.0010
# Epoch 144/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.4635 - val_loss: 0.4708 - lr: 0.0010
# Epoch 145/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.4836 - val_loss: 0.4872 - lr: 0.0010
# Epoch 146/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.4893 - val_loss: 0.4622 - lr: 0.0010
# Epoch 147/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.4770 - val_loss: 0.4832 - lr: 0.0010
# Epoch 148/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.4922 - val_loss: 0.4741 - lr: 0.0010
# Epoch 149/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.4760 - val_loss: 0.4653 - lr: 0.0010
# Epoch 150/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.4654 - val_loss: 0.4799 - lr: 0.0010
# Epoch 151/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.4819 - val_loss: 0.4677 - lr: 0.0010
# Epoch 152/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.4769 - val_loss: 0.4664 - lr: 0.0010
# Epoch 153/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.4808 - val_loss: 0.5262 - lr: 0.0010
# Epoch 154/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5244 - val_loss: 0.5136 - lr: 0.0010
# Epoch 155/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5187 - val_loss: 0.5079 - lr: 0.0010
# Epoch 156/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5107 - val_loss: 0.5218 - lr: 0.0010
# Epoch 157/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5029 - val_loss: 0.5243 - lr: 0.0010
# Epoch 158/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.4979 - val_loss: 0.5197 - lr: 0.0010
# Epoch 159/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5056 - val_loss: 0.4752 - lr: 0.0010
# Epoch 160/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.4971 - val_loss: 0.4819 - lr: 0.0010
# Epoch 161/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.5096 - val_loss: 0.4885 - lr: 0.0010
# Epoch 162/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.4978 - val_loss: 0.4694 - lr: 0.0010
# Epoch 163/500
# 4/4 [==============================] - 14s 4s/step - loss: 0.4722 - val_loss: 0.4727 - lr: 0.0010
# 4/4 [==============================] - 8s 906ms/step
# Validation RMSE: 0.6698795577100138

# %%
import matplotlib.pyplot as plt

# Assuming that one_lifeline is your data reshaped correctly for the model input
# Example: one_lifeline = np.random.rand(1, 376, 1)  # Use your actual reshaped data here

# Predict the reconstruction for the lifeline
reconstructed = autoencoder.predict(train_data)
lifeline = 5
feature = 6 

# Flatten the arrays to be able to plot them since they contain a single feature
scaled_series = train_data[lifeline,:,feature]
reconstructed_series = reconstructed[lifeline,:,feature]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(scaled_series, label='Original Data', color='blue')
plt.plot(reconstructed_series, label='Reconstructed Data', color='red', linestyle='--')
plt.title('Lifeline 1 for Single Feature')
plt.xlabel('Timepoint')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 4/4 [==============================] - 5s 1s/step

# %%
from tensorflow.keras.models import Model

# Assuming 'encoded' is the output of your last encoder layer and 'inputs' is your input layer
latent_model = Model(inputs, latent_space)
latent_representations = latent_model.predict(train_data)
# Out:
# 4/4 [==============================] - 3s 538ms/step

# %%
import pandas as pd

# Convert the latent representations to a DataFrame
latent_df = pd.DataFrame(latent_representations)

# Specify your desired Excel file path
excel_file_path = 'D:/Desktop/Work/Multiple Lifelines/latent_representations_100_lifelines.csv'

# Save the DataFrame to an Excel file
latent_df.to_csv(excel_file_path, index=False)

print(f"Latent representations saved to {excel_file_path}")
# Out:
# Latent representations saved to D:/Desktop/Work/Multiple Lifelines/latent_representations_100_lifelines.csv

# %% [markdown]
# # Only used biomass reaction

# %%
import os
import pandas as pd
import numpy as np

folder_path = '100_dFBA_Lifelines'
file_names = sorted(os.listdir(folder_path))

expected_timepoints = 376 # reduced timepoints by 10 for faster runs, just temporary 

for file_name in file_names:
    file_path = os.path.join(folder_path, file_name)
    lifeline_df = pd.read_csv(file_path, sep="\t", index_col=0)

    # Select every 10th row and ensure there are exactly 376 timepoints
    reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
    reduced_df.to_csv(file_path, sep="\t")

data_list = []
filtered_reactions = None

for file_name in file_names:
    file_path = os.path.join(folder_path, file_name)
    lifeline_df = pd.read_csv(file_path, sep="\t", index_col=0)

    if filtered_reactions is None:
        non_constant_fluxes_df = lifeline_df.loc[:, (lifeline_df != lifeline_df.iloc[0]).any()]
        unique_reactions_fluxes_df = non_constant_fluxes_df.loc[:, ~non_constant_fluxes_df.columns.duplicated()]
        filtered_reactions = unique_reactions_fluxes_df.columns

    filtered_lifeline_df = lifeline_df[filtered_reactions]

    if filtered_lifeline_df.shape != (expected_timepoints, len(filtered_reactions)):
        print(f"Shape mismatch for file: {file_name}. Expected ({expected_timepoints}, {len(filtered_reactions)}) but got {filtered_lifeline_df.shape}")

    data_list.append(filtered_lifeline_df.to_numpy())

data_3d = np.stack(data_list, axis=1)
print("Shape of the Big Matrix:", data_3d.shape)
# Out:
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_27696\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# Shape mismatch for file: lifeline_0_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_100_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_10_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_11_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_12_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_13_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_14_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_15_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_16_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_17_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_18_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_19_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_1_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_20_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_21_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_22_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_23_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_24_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_25_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_26_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_27_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_28_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_29_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_2_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_30_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_31_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_32_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_33_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_34_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_35_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_36_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_37_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_38_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_39_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_3_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_40_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_41_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_42_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_43_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_44_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_45_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_46_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_47_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_48_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_49_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_4_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_50_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_51_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_52_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_53_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_54_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_55_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_56_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_57_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_58_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_59_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_5_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_60_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_61_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_62_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_63_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_64_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_65_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_66_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_67_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_68_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_69_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_6_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_70_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_71_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_72_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_73_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_74_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_75_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_76_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_77_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_78_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_79_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_7_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_80_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_81_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_82_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_83_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_84_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_85_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_86_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_87_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_88_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_89_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_8_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_90_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_91_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_92_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_93_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_94_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_95_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_96_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_97_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_98_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_99_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape mismatch for file: lifeline_9_dFBA_pd_df.csv. Expected (376, 48) but got (38, 48)
# Shape of the Big Matrix: (38, 101, 48)

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# Assuming data_3d is original data with shape (n_timesteps, n_samples, n_features)
# Example: n_timesteps = 376, n_samples = 14, n_features = 48

n_timesteps, n_samples, n_features = data_3d.shape

# Initialize a StandardScaler for each feature for each sample
scalers = [[StandardScaler() for _ in range(n_features)] for _ in range(n_samples)]

# Normalized data will have the same shape as data_3d initially
normalized_data = np.empty_like(data_3d, dtype=float)

# Apply the scalers to each feature for each sample across all timesteps
for sample_index in range(n_samples):
    for feature_index in range(n_features):
        # Extract the feature data for the current sample
        feature_data = data_3d[:, sample_index, feature_index].reshape(-1, 1)
        
        # Fit and transform the data using the corresponding scaler
        normalized_feature_data = scalers[sample_index][feature_index].fit_transform(feature_data)
        
        # Assign the normalized data back to its position in the normalized_data array
        normalized_data[:, sample_index, feature_index] = normalized_feature_data.flatten()

# Transpose normalized_data to have the shape (n_samples, n_timesteps, n_features)
normalized_data = np.transpose(normalized_data, (1, 0, 2))

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, RepeatVector, TimeDistributed
from tensorflow.keras.initializers import glorot_uniform, he_normal
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# Assuming five_lifeline is a 3D array with the shape (1, 376, 48)
train_data = normalized_data
val_data = train_data  # Using the same data for validation as a placeholder

# Define the input layer with the shape (timesteps, features)
input_shape = (train_data.shape[1], train_data.shape[2])
inputs = Input(shape=input_shape)

# Encoder layers with glorot_uniform initializer
encoded = LSTM(400, activation='tanh', return_sequences=True,
               kernel_initializer=glorot_uniform(seed=0))(inputs)
encoded = LSTM(300, activation='tanh', return_sequences=True,
               kernel_initializer=glorot_uniform(seed=0))(encoded)
encoded = LSTM(200, activation='tanh', return_sequences=False,
               kernel_initializer=glorot_uniform(seed=0))(encoded)
# Latent space with he_normal initializer
latent_space = Dense(100, activation='tanh',
                     kernel_initializer=he_normal(seed=0))(encoded)

# Decoder layers, repeat the latent space at each timestep
decoded = RepeatVector(input_shape[0])(latent_space)
decoded = LSTM(200, activation='tanh', return_sequences=True,
               kernel_initializer=glorot_uniform(seed=0))(decoded)
decoded = LSTM(300, activation='tanh', return_sequences=True,
               kernel_initializer=glorot_uniform(seed=0))(decoded)
decoded = LSTM(400, activation='tanh', return_sequences=True,
               kernel_initializer=glorot_uniform(seed=0))(decoded)

# Output layer, reconstruct the original input
outputs = TimeDistributed(Dense(input_shape[1]))(decoded)

# Create the autoencoder model
autoencoder = Model(inputs, outputs)
autoencoder.compile(optimizer='adam', loss='mse')

# Summary of the model
autoencoder.summary()
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 38, 1)]           0
#
#  lstm_30 (LSTM)              (None, 38, 400)           643200
#
#  lstm_31 (LSTM)              (None, 38, 300)           841200
#
#  lstm_32 (LSTM)              (None, 200)               400800
#
#  dense_10 (Dense)            (None, 100)               20100
#
#  repeat_vector_5 (RepeatVec  (None, 38, 100)           0
#  tor)
#
#  lstm_33 (LSTM)              (None, 38, 200)           240800
#
#  lstm_34 (LSTM)              (None, 38, 300)           601200
#
#  lstm_35 (LSTM)              (None, 38, 400)           1121600
#
#  time_distributed_5 (TimeDi  (None, 38, 1)             401
#  stributed)
#
# =================================================================
# Total params: 3869301 (14.76 MB)
# Trainable params: 3869301 (14.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Callbacks
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=20, min_lr=0.00001)
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Fit the model
history = autoencoder.fit(
    train_data,
    train_data,
    epochs = 500,
    batch_size=32,  # Adjust the batch size if necessary
    validation_data=(val_data, val_data),
    callbacks=[reduce_lr, early_stop]
)

# Predict on the validation set
val_predictions = autoencoder.predict(val_data)

# Compute mean squared error on the validation set
mean_squared_error = np.mean(np.square(val_data - val_predictions))

# Compute root mean squared error (RMSE)
reconstruction_loss = np.sqrt(mean_squared_error)
print(f"Validation RMSE: {reconstruction_loss}")
# Out:
# Epoch 1/500
# 4/4 [==============================] - 23s 4s/step - loss: 1.2687 - val_loss: 0.9953 - lr: 0.0010
# Epoch 2/500
# 4/4 [==============================] - 12s 3s/step - loss: 0.9991 - val_loss: 0.9954 - lr: 0.0010
# Epoch 3/500
# 4/4 [==============================] - 11s 3s/step - loss: 0.9908 - val_loss: 0.9740 - lr: 0.0010
# Epoch 4/500
# 4/4 [==============================] - 11s 3s/step - loss: 0.9704 - val_loss: 0.9601 - lr: 0.0010
# Epoch 5/500
# 4/4 [==============================] - 11s 3s/step - loss: 0.9608 - val_loss: 0.9573 - lr: 0.0010
# Epoch 6/500
# 4/4 [==============================] - 11s 3s/step - loss: 0.9493 - val_loss: 0.9355 - lr: 0.0010
# Epoch 7/500
# 4/4 [==============================] - 10s 3s/step - loss: 0.9302 - val_loss: 0.9250 - lr: 0.0010
# Epoch 8/500
# 4/4 [==============================] - 11s 3s/step - loss: 0.9160 - val_loss: 0.8943 - lr: 0.0010
# Epoch 9/500
# 4/4 [==============================] - 11s 3s/step - loss: 0.8892 - val_loss: 0.8696 - lr: 0.0010
# Epoch 10/500
# 4/4 [==============================] - 11s 3s/step - loss: 0.8673 - val_loss: 0.8552 - lr: 0.0010
# Epoch 11/500
# 4/4 [==============================] - 11s 3s/step - loss: 0.8532 - val_loss: 0.8557 - lr: 0.0010
# Epoch 12/500
# 4/4 [==============================] - 11s 3s/step - loss: 0.8506 - val_loss: 0.8456 - lr: 0.0010
# Epoch 13/500
# 4/4 [==============================] - 11s 3s/step - loss: 0.8347 - val_loss: 0.8128 - lr: 0.0010
# Epoch 14/500
# 4/4 [==============================] - 11s 3s/step - loss: 0.7996 - val_loss: 0.7702 - lr: 0.0010
# Epoch 15/500
# 4/4 [==============================] - 10s 3s/step - loss: 0.7802 - val_loss: 0.7893 - lr: 0.0010
# Epoch 16/500
# 4/4 [==============================] - 10s 3s/step - loss: 0.7976 - val_loss: 0.7661 - lr: 0.0010
# Epoch 17/500
# 4/4 [==============================] - 10s 3s/step - loss: 0.7753 - val_loss: 0.7717 - lr: 0.0010
# Epoch 18/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.7678 - val_loss: 0.7537 - lr: 0.0010
# Epoch 19/500
# 4/4 [==============================] - 10s 3s/step - loss: 0.7487 - val_loss: 0.7666 - lr: 0.0010
# Epoch 20/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.7667 - val_loss: 0.7826 - lr: 0.0010
# Epoch 21/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.7762 - val_loss: 0.7388 - lr: 0.0010
# Epoch 22/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.7392 - val_loss: 0.7346 - lr: 0.0010
# Epoch 23/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.7376 - val_loss: 0.7555 - lr: 0.0010
# Epoch 24/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.7505 - val_loss: 0.7445 - lr: 0.0010
# Epoch 25/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.7495 - val_loss: 0.7454 - lr: 0.0010
# Epoch 26/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.7483 - val_loss: 0.7465 - lr: 0.0010
# Epoch 27/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.7296 - val_loss: 0.7299 - lr: 0.0010
# Epoch 28/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.7181 - val_loss: 0.7283 - lr: 0.0010
# Epoch 29/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.7095 - val_loss: 0.7574 - lr: 0.0010
# Epoch 30/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.7318 - val_loss: 0.7243 - lr: 0.0010
# Epoch 31/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.7259 - val_loss: 0.7032 - lr: 0.0010
# Epoch 32/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.6939 - val_loss: 0.6970 - lr: 0.0010
# Epoch 33/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.6964 - val_loss: 0.6855 - lr: 0.0010
# Epoch 34/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.6810 - val_loss: 0.6848 - lr: 0.0010
# Epoch 35/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.6868 - val_loss: 0.6771 - lr: 0.0010
# Epoch 36/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.6803 - val_loss: 0.6880 - lr: 0.0010
# Epoch 37/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.6720 - val_loss: 0.6953 - lr: 0.0010
# Epoch 38/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.6883 - val_loss: 0.6914 - lr: 0.0010
# Epoch 39/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.7047 - val_loss: 0.6578 - lr: 0.0010
# Epoch 40/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.6655 - val_loss: 0.6604 - lr: 0.0010
# Epoch 41/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.6776 - val_loss: 0.6668 - lr: 0.0010
# Epoch 42/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.6661 - val_loss: 0.6707 - lr: 0.0010
# Epoch 43/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.6598 - val_loss: 0.6550 - lr: 0.0010
# Epoch 44/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.6600 - val_loss: 0.6588 - lr: 0.0010
# Epoch 45/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.6683 - val_loss: 0.6675 - lr: 0.0010
# Epoch 46/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.6567 - val_loss: 0.6432 - lr: 0.0010
# Epoch 47/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.6418 - val_loss: 0.6398 - lr: 0.0010
# Epoch 48/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.6394 - val_loss: 0.6338 - lr: 0.0010
# Epoch 49/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.6228 - val_loss: 0.6585 - lr: 0.0010
# Epoch 50/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.6310 - val_loss: 0.6411 - lr: 0.0010
# Epoch 51/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.6266 - val_loss: 0.6122 - lr: 0.0010
# Epoch 52/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.6210 - val_loss: 0.6022 - lr: 0.0010
# Epoch 53/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5999 - val_loss: 0.6006 - lr: 0.0010
# Epoch 54/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5988 - val_loss: 0.5962 - lr: 0.0010
# Epoch 55/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.5952 - val_loss: 0.5954 - lr: 0.0010
# Epoch 56/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5871 - val_loss: 0.5923 - lr: 0.0010
# Epoch 57/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5999 - val_loss: 0.5865 - lr: 0.0010
# Epoch 58/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5869 - val_loss: 0.5864 - lr: 0.0010
# Epoch 59/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5938 - val_loss: 0.6005 - lr: 0.0010
# Epoch 60/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5855 - val_loss: 0.5758 - lr: 0.0010
# Epoch 61/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5728 - val_loss: 0.5737 - lr: 0.0010
# Epoch 62/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5715 - val_loss: 0.5872 - lr: 0.0010
# Epoch 63/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5770 - val_loss: 0.5715 - lr: 0.0010
# Epoch 64/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5691 - val_loss: 0.5750 - lr: 0.0010
# Epoch 65/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5728 - val_loss: 0.5674 - lr: 0.0010
# Epoch 66/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5673 - val_loss: 0.5544 - lr: 0.0010
# Epoch 67/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5625 - val_loss: 0.5834 - lr: 0.0010
# Epoch 68/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5882 - val_loss: 0.5770 - lr: 0.0010
# Epoch 69/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.5766 - val_loss: 0.5671 - lr: 0.0010
# Epoch 70/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5788 - val_loss: 0.5723 - lr: 0.0010
# Epoch 71/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5759 - val_loss: 0.5698 - lr: 0.0010
# Epoch 72/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5679 - val_loss: 0.5726 - lr: 0.0010
# Epoch 73/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5652 - val_loss: 0.5663 - lr: 0.0010
# Epoch 74/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.5736 - val_loss: 0.5576 - lr: 0.0010
# Epoch 75/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5650 - val_loss: 0.5557 - lr: 0.0010
# Epoch 76/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5673 - val_loss: 0.5645 - lr: 0.0010
# Epoch 77/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5594 - val_loss: 0.5676 - lr: 0.0010
# Epoch 78/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5618 - val_loss: 0.5562 - lr: 0.0010
# Epoch 79/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5650 - val_loss: 0.5580 - lr: 0.0010
# Epoch 80/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5638 - val_loss: 0.5509 - lr: 0.0010
# Epoch 81/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5523 - val_loss: 0.5461 - lr: 0.0010
# Epoch 82/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5471 - val_loss: 0.5378 - lr: 0.0010
# Epoch 83/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5384 - val_loss: 0.5375 - lr: 0.0010
# Epoch 84/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5350 - val_loss: 0.5315 - lr: 0.0010
# Epoch 85/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5305 - val_loss: 0.5276 - lr: 0.0010
# Epoch 86/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5321 - val_loss: 0.5379 - lr: 0.0010
# Epoch 87/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5398 - val_loss: 0.5300 - lr: 0.0010
# Epoch 88/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.5341 - val_loss: 0.5401 - lr: 0.0010
# Epoch 89/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.5326 - val_loss: 0.5287 - lr: 0.0010
# Epoch 90/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5320 - val_loss: 0.5223 - lr: 0.0010
# Epoch 91/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5274 - val_loss: 0.5220 - lr: 0.0010
# Epoch 92/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5256 - val_loss: 0.5217 - lr: 0.0010
# Epoch 93/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5243 - val_loss: 0.5207 - lr: 0.0010
# Epoch 94/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5247 - val_loss: 0.5361 - lr: 0.0010
# Epoch 95/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5278 - val_loss: 0.5097 - lr: 0.0010
# Epoch 96/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5244 - val_loss: 0.5299 - lr: 0.0010
# Epoch 97/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5370 - val_loss: 0.5199 - lr: 0.0010
# Epoch 98/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5229 - val_loss: 0.5304 - lr: 0.0010
# Epoch 99/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5305 - val_loss: 0.5358 - lr: 0.0010
# Epoch 100/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5274 - val_loss: 0.5572 - lr: 0.0010
# Epoch 101/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5340 - val_loss: 0.5526 - lr: 0.0010
# Epoch 102/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5444 - val_loss: 0.5625 - lr: 0.0010
# Epoch 103/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.5550 - val_loss: 0.5375 - lr: 0.0010
# Epoch 104/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5398 - val_loss: 0.5224 - lr: 0.0010
# Epoch 105/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.5478 - val_loss: 0.5315 - lr: 0.0010
# Epoch 106/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5358 - val_loss: 0.5355 - lr: 0.0010
# Epoch 107/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.5212 - val_loss: 0.5174 - lr: 0.0010
# Epoch 108/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5236 - val_loss: 0.5198 - lr: 0.0010
# Epoch 109/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5147 - val_loss: 0.5222 - lr: 0.0010
# Epoch 110/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5199 - val_loss: 0.4977 - lr: 0.0010
# Epoch 111/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5221 - val_loss: 0.5009 - lr: 0.0010
# Epoch 112/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.5151 - val_loss: 0.5236 - lr: 0.0010
# Epoch 113/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5411 - val_loss: 0.5159 - lr: 0.0010
# Epoch 114/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5288 - val_loss: 0.5387 - lr: 0.0010
# Epoch 115/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5548 - val_loss: 0.5354 - lr: 0.0010
# Epoch 116/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5565 - val_loss: 0.5552 - lr: 0.0010
# Epoch 117/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5491 - val_loss: 0.5244 - lr: 0.0010
# Epoch 118/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5269 - val_loss: 0.5173 - lr: 0.0010
# Epoch 119/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5195 - val_loss: 0.4975 - lr: 0.0010
# Epoch 120/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5000 - val_loss: 0.4941 - lr: 0.0010
# Epoch 121/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.4910 - val_loss: 0.4968 - lr: 0.0010
# Epoch 122/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.5131 - val_loss: 0.5030 - lr: 0.0010
# Epoch 123/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4970 - val_loss: 0.4965 - lr: 0.0010
# Epoch 124/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4891 - val_loss: 0.4880 - lr: 0.0010
# Epoch 125/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.4893 - val_loss: 0.5001 - lr: 0.0010
# Epoch 126/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4952 - val_loss: 0.4958 - lr: 0.0010
# Epoch 127/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.5044 - val_loss: 0.4864 - lr: 0.0010
# Epoch 128/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4823 - val_loss: 0.4964 - lr: 0.0010
# Epoch 129/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4967 - val_loss: 0.4877 - lr: 0.0010
# Epoch 130/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4865 - val_loss: 0.4664 - lr: 0.0010
# Epoch 131/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4763 - val_loss: 0.5153 - lr: 0.0010
# Epoch 132/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5191 - val_loss: 0.5467 - lr: 0.0010
# Epoch 133/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.5386 - val_loss: 0.5214 - lr: 0.0010
# Epoch 134/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5241 - val_loss: 0.5593 - lr: 0.0010
# Epoch 135/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5483 - val_loss: 0.5501 - lr: 0.0010
# Epoch 136/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5327 - val_loss: 0.5363 - lr: 0.0010
# Epoch 137/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5551 - val_loss: 0.5553 - lr: 0.0010
# Epoch 138/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5772 - val_loss: 0.5524 - lr: 0.0010
# Epoch 139/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5631 - val_loss: 0.5588 - lr: 0.0010
# Epoch 140/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5594 - val_loss: 0.5349 - lr: 0.0010
# Epoch 141/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5291 - val_loss: 0.5131 - lr: 0.0010
# Epoch 142/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5148 - val_loss: 0.4975 - lr: 0.0010
# Epoch 143/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4958 - val_loss: 0.4907 - lr: 0.0010
# Epoch 144/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4914 - val_loss: 0.4788 - lr: 0.0010
# Epoch 145/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4919 - val_loss: 0.4863 - lr: 0.0010
# Epoch 146/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4862 - val_loss: 0.4761 - lr: 0.0010
# Epoch 147/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4832 - val_loss: 0.4803 - lr: 0.0010
# Epoch 148/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4775 - val_loss: 0.4727 - lr: 0.0010
# Epoch 149/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.4738 - val_loss: 0.4613 - lr: 0.0010
# Epoch 150/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4649 - val_loss: 0.4572 - lr: 0.0010
# Epoch 151/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4639 - val_loss: 0.5114 - lr: 0.0010
# Epoch 152/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.4871 - val_loss: 0.5139 - lr: 0.0010
# Epoch 153/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4908 - val_loss: 0.4952 - lr: 0.0010
# Epoch 154/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4945 - val_loss: 0.4708 - lr: 0.0010
# Epoch 155/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4640 - val_loss: 0.4590 - lr: 0.0010
# Epoch 156/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.4645 - val_loss: 0.4501 - lr: 0.0010
# Epoch 157/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.4481 - val_loss: 0.4407 - lr: 0.0010
# Epoch 158/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4484 - val_loss: 0.5207 - lr: 0.0010
# Epoch 159/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5168 - val_loss: 0.4905 - lr: 0.0010
# Epoch 160/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.5005 - val_loss: 0.4974 - lr: 0.0010
# Epoch 161/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.5046 - val_loss: 0.4897 - lr: 0.0010
# Epoch 162/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.4848 - val_loss: 0.4691 - lr: 0.0010
# Epoch 163/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4665 - val_loss: 0.4544 - lr: 0.0010
# Epoch 164/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4570 - val_loss: 0.4784 - lr: 0.0010
# Epoch 165/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.4733 - val_loss: 0.5117 - lr: 0.0010
# Epoch 166/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.4776 - val_loss: 0.4935 - lr: 0.0010
# Epoch 167/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4921 - val_loss: 0.4717 - lr: 0.0010
# Epoch 168/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4759 - val_loss: 0.4824 - lr: 0.0010
# Epoch 169/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4763 - val_loss: 0.4530 - lr: 0.0010
# Epoch 170/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4560 - val_loss: 0.4615 - lr: 0.0010
# Epoch 171/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4626 - val_loss: 0.4942 - lr: 0.0010
# Epoch 172/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4745 - val_loss: 0.4486 - lr: 0.0010
# Epoch 173/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4639 - val_loss: 0.4710 - lr: 0.0010
# Epoch 174/500
# 4/4 [==============================] - 10s 2s/step - loss: 0.4750 - val_loss: 0.4476 - lr: 0.0010
# Epoch 175/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4510 - val_loss: 0.4422 - lr: 0.0010
# Epoch 176/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4460 - val_loss: 0.4554 - lr: 0.0010
# Epoch 177/500
# 4/4 [==============================] - 9s 2s/step - loss: 0.4500 - val_loss: 0.4454 - lr: 0.0010
# 4/4 [==============================] - 4s 388ms/step
# Validation RMSE: 0.6638427268489581

# %%
import matplotlib.pyplot as plt

# Assuming that one_lifeline is your data reshaped correctly for the model input
# Example: one_lifeline = np.random.rand(1, 376, 1)  # Use your actual reshaped data here

# Predict the reconstruction for the lifeline
reconstructed = autoencoder.predict(train_data)
lifeline = 5
feature = 0 

# Flatten the arrays to be able to plot them since they contain a single feature
scaled_series = train_data[lifeline,:,feature]
reconstructed_series = reconstructed[lifeline,:,feature]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(scaled_series, label='Original Data', color='blue')
plt.plot(reconstructed_series, label='Reconstructed Data', color='red', linestyle='--')
plt.title('Lifeline 1 for Single Feature')
plt.xlabel('Timepoint')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 4/4 [==============================] - 2s 418ms/step

# %%
from tensorflow.keras.models import Model

# Assuming 'encoded' is the output of your last encoder layer and 'inputs' is your input layer
latent_model = Model(inputs, latent_space)
latent_representations = latent_model.predict(train_data)
# Out:
# 4/4 [==============================] - 2s 287ms/step

# %%
import pandas as pd

# Convert the latent representations to a DataFrame
latent_df = pd.DataFrame(latent_representations)

# Specify your desired Excel file path
excel_file_path = 'D:/Desktop/Work/Multiple Lifelines/latent_representations_100_lifelines_just_biomass.csv'

# Save the DataFrame to an Excel file
latent_df.to_csv(excel_file_path, index=False)

print(f"Latent representations saved to {excel_file_path}")
# Out:
# Latent representations saved to D:/Desktop/Work/Multiple Lifelines/latent_representations_100_lifelines_just_biomass.csv

# %%
lifelines_to_clusters = pd.read_csv('lifelines_to_clusters.csv')

# %%
lifelines_to_clusters
# Out:
#      Unnamed: 0  cluster
# 0            28        1
# 1            80        2
# 2            22        2
# 3             9        3
# 4             5        4
# ..          ...      ...
# 96           61        1
# 97           59        1
# 98           83        1
# 99          101        2
# 100          30        4
#
# [101 rows x 2 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file with lifeline-cluster pairs
lifelines_to_clusters = pd.read_csv('lifelines_to_clusters.csv')
lifelines_to_clusters.columns = ['lifeline', 'cluster']

# Determine the number of clusters
num_clusters = lifelines_to_clusters['cluster'].nunique()

# Setup the figure and axes for a 3x3 grid
fig, axes = plt.subplots(3, 3, figsize=(15, 15))  # Adjust the size as needed
axes = axes.flatten()  # Flatten the 2D array of axes for easy iteration

# Create a plot for each cluster on its own subplot
for cluster_id in range(1, num_clusters + 1):
    # Find all lifelines belonging to the current cluster
    lifelines_in_cluster = lifelines_to_clusters[lifelines_to_clusters['cluster'] == cluster_id]['lifeline']
    
    # Get the corresponding subplot axis
    ax = axes[cluster_id - 1]
    
    # Plot each lifeline in the cluster
    for lifeline in lifelines_in_cluster:
        # Adjust lifeline index for zero-based indexing
        adjusted_lifeline_index = lifeline - 1
        
        # Extract the lifeline data from train_data
        # Replace 'feature' with the correct index for your feature
        lifeline_data = train_data[adjusted_lifeline_index, :, feature]  
        ax.plot(lifeline_data, label=f'Lifeline {lifeline}')
    
    # Set titles and labels for each subplot
    ax.set_title(f'Cluster {cluster_id}')
    ax.set_xlabel('Time or Sequence')
    ax.set_ylabel('Feature Value')
    ax.legend()

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %% [markdown]
# # Latent Space for Each Timestep

# %%
import os
import pandas as pd
import numpy as np

folder_path = '100_dFBA_Lifelines'
file_names = sorted(os.listdir(folder_path))

expected_timepoints = 376 # reduced timepoints by 10 for faster runs, just temporary 

for file_name in file_names:
    file_path = os.path.join(folder_path, file_name)
    lifeline_df = pd.read_csv(file_path, sep="\t", index_col=0)

    # Select every 10th row and ensure there are exactly 376 timepoints
    reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
    reduced_df.to_csv(file_path, sep="\t")

data_list = []
filtered_reactions = None

for file_name in file_names:
    file_path = os.path.join(folder_path, file_name)
    lifeline_df = pd.read_csv(file_path, sep="\t", index_col=0)

    if filtered_reactions is None:
        non_constant_fluxes_df = lifeline_df.loc[:, (lifeline_df != lifeline_df.iloc[0]).any()]
        unique_reactions_fluxes_df = non_constant_fluxes_df.loc[:, ~non_constant_fluxes_df.columns.duplicated()]
        filtered_reactions = unique_reactions_fluxes_df.columns

    filtered_lifeline_df = lifeline_df[filtered_reactions]

    if filtered_lifeline_df.shape != (expected_timepoints, len(filtered_reactions)):
        print(f"Shape mismatch for file: {file_name}. Expected ({expected_timepoints}, {len(filtered_reactions)}) but got {filtered_lifeline_df.shape}")

    data_list.append(filtered_lifeline_df.to_numpy())

data_3d = np.stack(data_list, axis=1)
print("Shape of the Big Matrix:", data_3d.shape)
# Out:
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# C:\Users\elysi\AppData\Local\Temp\ipykernel_7048\597854438.py:15: FutureWarning: The behavior of obj[i:j] with a float-dtype index is deprecated. In a future version, this will be treated as positional instead of label-based. For label-based slicing, use obj.loc[i:j] instead
#   reduced_df = lifeline_df.iloc[::10][:expected_timepoints]
# Shape of the Big Matrix: (376, 101, 48)

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# Assuming data_3d is original data with shape (n_timesteps, n_samples, n_features)
# Example: n_timesteps = 376, n_samples = 14, n_features = 48

n_timesteps, n_samples, n_features = data_3d.shape

# Initialize a StandardScaler for each feature for each sample
scalers = [[StandardScaler() for _ in range(n_features)] for _ in range(n_samples)]

# Normalized data will have the same shape as data_3d initially
normalized_data = np.empty_like(data_3d, dtype=float)

# Apply the scalers to each feature for each sample across all timesteps
for sample_index in range(n_samples):
    for feature_index in range(n_features):
        # Extract the feature data for the current sample
        feature_data = data_3d[:, sample_index, feature_index].reshape(-1, 1)
        
        # Fit and transform the data using the corresponding scaler
        normalized_feature_data = scalers[sample_index][feature_index].fit_transform(feature_data)
        
        # Assign the normalized data back to its position in the normalized_data array
        normalized_data[:, sample_index, feature_index] = normalized_feature_data.flatten()

# Transpose normalized_data to have the shape (n_samples, n_timesteps, n_features)
normalized_data = np.transpose(normalized_data, (1, 0, 2))

# %%
normalized_data.shape
# Out:
# (101, 38, 48)

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, TimeDistributed
from tensorflow.keras.initializers import glorot_uniform, he_normal
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# Assuming train_data is a 3D array with the shape (1, 376, 48)
train_data = normalized_data
val_data = train_data  # Using the same data for validation as a placeholder

# Define the input layer with the shape (timesteps, features)
input_shape = (train_data.shape[1], train_data.shape[2])
inputs = Input(shape=input_shape)

# Encoder layers with glorot_uniform initializer
encoded = LSTM(400, activation='tanh', return_sequences=True,
               kernel_initializer=glorot_uniform(seed=0))(inputs)
encoded = LSTM(200, activation='tanh', return_sequences=True,
               kernel_initializer=glorot_uniform(seed=0))(encoded)
# This LSTM layer now returns sequences, providing a latent vector for each timestep
encoded = LSTM(30, activation='tanh', return_sequences=True,
               kernel_initializer=glorot_uniform(seed=0))(encoded)

# Decoder layers
# No need for RepeatVector since we're returning sequences in the encoder
decoded = LSTM(30, activation='tanh', return_sequences=True,
               kernel_initializer=glorot_uniform(seed=0))(encoded)
decoded = LSTM(200, activation='tanh', return_sequences=True,
               kernel_initializer=glorot_uniform(seed=0))(decoded)
decoded = LSTM(400, activation='tanh', return_sequences=True,
               kernel_initializer=glorot_uniform(seed=0))(decoded)

# Output layer, reconstruct the original input at each timestep
outputs = TimeDistributed(Dense(input_shape[1]))(decoded)

# Create the autoencoder model
autoencoder = Model(inputs, outputs)
autoencoder.compile(optimizer='adam', loss='mse')

# Summary of the model
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 376, 48)]         0
#
#  lstm (LSTM)                 (None, 376, 400)          718400
#
#  lstm_1 (LSTM)               (None, 376, 200)          480800
#
#  lstm_2 (LSTM)               (None, 376, 30)           27720
#
#  lstm_3 (LSTM)               (None, 376, 30)           7320
#
#  lstm_4 (LSTM)               (None, 376, 200)          184800
#
#  lstm_5 (LSTM)               (None, 376, 400)          961600
#
#  time_distributed (TimeDist  (None, 376, 48)           19248
#  ributed)
#
# =================================================================
# Total params: 2399888 (9.15 MB)
# Trainable params: 2399888 (9.15 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Callbacks
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=20, min_lr=0.00001)
early_stop = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Fit the model
history = autoencoder.fit(
    train_data,
    train_data,
    epochs = 70,
    batch_size=32,  # Adjust the batch size if necessary
    validation_data=(val_data, val_data),
    callbacks=[reduce_lr, early_stop]
)

# Predict on the validation set
val_predictions = autoencoder.predict(val_data)

# Compute mean squared error on the validation set
mean_squared_error = np.mean(np.square(val_data - val_predictions))

# Compute root mean squared error (RMSE)
reconstruction_loss = np.sqrt(mean_squared_error)
print(f"Validation RMSE: {reconstruction_loss}")
# Out:
# Epoch 1/70
# 4/4 [==============================] - 40s 10s/step - loss: 0.6867 - val_loss: 0.6033 - lr: 0.0010
# Epoch 2/70
# 4/4 [==============================] - 36s 9s/step - loss: 0.5900 - val_loss: 0.5135 - lr: 0.0010
# Epoch 3/70
# 4/4 [==============================] - 33s 8s/step - loss: 0.5221 - val_loss: 0.4631 - lr: 0.0010
# Epoch 4/70
# 4/4 [==============================] - 34s 8s/step - loss: 0.4423 - val_loss: 0.3888 - lr: 0.0010
# Epoch 5/70
# 4/4 [==============================] - 35s 9s/step - loss: 0.3638 - val_loss: 0.3056 - lr: 0.0010
# Epoch 6/70
# 4/4 [==============================] - 39s 10s/step - loss: 0.2860 - val_loss: 0.3081 - lr: 0.0010
# Epoch 7/70
# 4/4 [==============================] - 40s 10s/step - loss: 0.2597 - val_loss: 0.2139 - lr: 0.0010
# Epoch 8/70
# 4/4 [==============================] - 41s 10s/step - loss: 0.2044 - val_loss: 0.1739 - lr: 0.0010
# Epoch 9/70
# 4/4 [==============================] - 42s 11s/step - loss: 0.1679 - val_loss: 0.1473 - lr: 0.0010
# Epoch 10/70
# 4/4 [==============================] - 39s 10s/step - loss: 0.1401 - val_loss: 0.1284 - lr: 0.0010
# Epoch 11/70
# 4/4 [==============================] - 39s 9s/step - loss: 0.1303 - val_loss: 0.1056 - lr: 0.0010
# Epoch 12/70
# 4/4 [==============================] - 36s 9s/step - loss: 0.1227 - val_loss: 0.1012 - lr: 0.0010
# Epoch 13/70
# 4/4 [==============================] - 37s 9s/step - loss: 0.1193 - val_loss: 0.1077 - lr: 0.0010
# Epoch 14/70
# 4/4 [==============================] - 36s 9s/step - loss: 0.1037 - val_loss: 0.0865 - lr: 0.0010
# Epoch 15/70
# 4/4 [==============================] - 36s 9s/step - loss: 0.0916 - val_loss: 0.0876 - lr: 0.0010
# Epoch 16/70
# 4/4 [==============================] - 37s 9s/step - loss: 0.0833 - val_loss: 0.0770 - lr: 0.0010
# Epoch 17/70
# 4/4 [==============================] - 37s 9s/step - loss: 0.0759 - val_loss: 0.0707 - lr: 0.0010
# Epoch 18/70
# 4/4 [==============================] - 37s 9s/step - loss: 0.0691 - val_loss: 0.0647 - lr: 0.0010
# Epoch 19/70
# 4/4 [==============================] - 37s 9s/step - loss: 0.0645 - val_loss: 0.0616 - lr: 0.0010
# Epoch 20/70
# 4/4 [==============================] - 36s 9s/step - loss: 0.0608 - val_loss: 0.0609 - lr: 0.0010
# Epoch 21/70
# 4/4 [==============================] - 37s 9s/step - loss: 0.0601 - val_loss: 0.0559 - lr: 0.0010
# Epoch 22/70
# 4/4 [==============================] - 38s 9s/step - loss: 0.0555 - val_loss: 0.0527 - lr: 0.0010
# Epoch 23/70
# 4/4 [==============================] - 37s 9s/step - loss: 0.0528 - val_loss: 0.0510 - lr: 0.0010
# Epoch 24/70
# 4/4 [==============================] - 37s 9s/step - loss: 0.0530 - val_loss: 0.0617 - lr: 0.0010
# Epoch 25/70
# 4/4 [==============================] - 38s 9s/step - loss: 0.0606 - val_loss: 0.0525 - lr: 0.0010
# Epoch 26/70
# 4/4 [==============================] - 40s 10s/step - loss: 0.0534 - val_loss: 0.0512 - lr: 0.0010
# Epoch 27/70
# 4/4 [==============================] - 40s 10s/step - loss: 0.0514 - val_loss: 0.0493 - lr: 0.0010
# Epoch 28/70
# 4/4 [==============================] - 40s 10s/step - loss: 0.0491 - val_loss: 0.0475 - lr: 0.0010
# Epoch 29/70
# 4/4 [==============================] - 39s 9s/step - loss: 0.0482 - val_loss: 0.0456 - lr: 0.0010
# Epoch 30/70
# 4/4 [==============================] - 40s 10s/step - loss: 0.0455 - val_loss: 0.0434 - lr: 0.0010
# Epoch 31/70
# 4/4 [==============================] - 41s 10s/step - loss: 0.0429 - val_loss: 0.0405 - lr: 0.0010
# Epoch 32/70
# 4/4 [==============================] - 39s 10s/step - loss: 0.0395 - val_loss: 0.0396 - lr: 0.0010
# Epoch 33/70
# 4/4 [==============================] - 42s 10s/step - loss: 0.0406 - val_loss: 0.0405 - lr: 0.0010
# Epoch 34/70
# 4/4 [==============================] - 41s 10s/step - loss: 0.0392 - val_loss: 0.0380 - lr: 0.0010
# Epoch 35/70
# 4/4 [==============================] - 43s 11s/step - loss: 0.0368 - val_loss: 0.0370 - lr: 0.0010
# Epoch 36/70
# 4/4 [==============================] - 41s 10s/step - loss: 0.0388 - val_loss: 0.0365 - lr: 0.0010
# Epoch 37/70
# 4/4 [==============================] - 40s 10s/step - loss: 0.0360 - val_loss: 0.0333 - lr: 0.0010
# Epoch 38/70
# 4/4 [==============================] - 39s 10s/step - loss: 0.0345 - val_loss: 0.0320 - lr: 0.0010
# Epoch 39/70
# 4/4 [==============================] - 42s 11s/step - loss: 0.0328 - val_loss: 0.0304 - lr: 0.0010
# Epoch 40/70
# 4/4 [==============================] - 44s 11s/step - loss: 0.0301 - val_loss: 0.0293 - lr: 0.0010
# Epoch 41/70
# 4/4 [==============================] - 41s 10s/step - loss: 0.0293 - val_loss: 0.0309 - lr: 0.0010
# Epoch 42/70
# 4/4 [==============================] - 42s 11s/step - loss: 0.0359 - val_loss: 0.0538 - lr: 0.0010
# Epoch 43/70
# 4/4 [==============================] - 42s 10s/step - loss: 0.0439 - val_loss: 0.0377 - lr: 0.0010
# Epoch 44/70
# 4/4 [==============================] - 43s 11s/step - loss: 0.0413 - val_loss: 0.0397 - lr: 0.0010
# Epoch 45/70
# 4/4 [==============================] - 44s 11s/step - loss: 0.0385 - val_loss: 0.0461 - lr: 0.0010
# Epoch 46/70
# 4/4 [==============================] - 43s 11s/step - loss: 0.0385 - val_loss: 0.0358 - lr: 0.0010
# Epoch 47/70
# 4/4 [==============================] - 44s 11s/step - loss: 0.0338 - val_loss: 0.0321 - lr: 0.0010
# Epoch 48/70
# 4/4 [==============================] - 42s 10s/step - loss: 0.0309 - val_loss: 0.0320 - lr: 0.0010
# Epoch 49/70
# 4/4 [==============================] - 45s 11s/step - loss: 0.0304 - val_loss: 0.0293 - lr: 0.0010
# Epoch 50/70
# 4/4 [==============================] - 43s 11s/step - loss: 0.0282 - val_loss: 0.0283 - lr: 0.0010
# Epoch 51/70
# 4/4 [==============================] - 43s 11s/step - loss: 0.0274 - val_loss: 0.0275 - lr: 0.0010
# Epoch 52/70
# 4/4 [==============================] - 42s 10s/step - loss: 0.0267 - val_loss: 0.0271 - lr: 0.0010
# Epoch 53/70
# 4/4 [==============================] - 42s 10s/step - loss: 0.0265 - val_loss: 0.0249 - lr: 0.0010
# Epoch 54/70
# 4/4 [==============================] - 43s 10s/step - loss: 0.0250 - val_loss: 0.0240 - lr: 0.0010
# Epoch 55/70
# 4/4 [==============================] - 40s 10s/step - loss: 0.0243 - val_loss: 0.0243 - lr: 0.0010
# Epoch 56/70
# 4/4 [==============================] - 42s 11s/step - loss: 0.0237 - val_loss: 0.0237 - lr: 0.0010
# Epoch 57/70
# 4/4 [==============================] - 43s 10s/step - loss: 0.0235 - val_loss: 0.0229 - lr: 0.0010
# Epoch 58/70
# 4/4 [==============================] - 40s 10s/step - loss: 0.0227 - val_loss: 0.0228 - lr: 0.0010
# Epoch 59/70
# 4/4 [==============================] - 39s 10s/step - loss: 0.0222 - val_loss: 0.0233 - lr: 0.0010
# Epoch 60/70
# 4/4 [==============================] - 39s 10s/step - loss: 0.0225 - val_loss: 0.0215 - lr: 0.0010
# Epoch 61/70
# 4/4 [==============================] - 41s 10s/step - loss: 0.0216 - val_loss: 0.0216 - lr: 0.0010
# Epoch 62/70
# 4/4 [==============================] - 41s 10s/step - loss: 0.0227 - val_loss: 0.0231 - lr: 0.0010
# Epoch 63/70
# 4/4 [==============================] - 42s 11s/step - loss: 0.0218 - val_loss: 0.0208 - lr: 0.0010
# Epoch 64/70
# 4/4 [==============================] - 44s 11s/step - loss: 0.0208 - val_loss: 0.0234 - lr: 0.0010
# Epoch 65/70
# 4/4 [==============================] - 42s 10s/step - loss: 0.0231 - val_loss: 0.0234 - lr: 0.0010
# Epoch 66/70
# 4/4 [==============================] - 43s 11s/step - loss: 0.0232 - val_loss: 0.0229 - lr: 0.0010
# Epoch 67/70
# 4/4 [==============================] - 42s 10s/step - loss: 0.0215 - val_loss: 0.0201 - lr: 0.0010
# Epoch 68/70
# 4/4 [==============================] - 40s 10s/step - loss: 0.0199 - val_loss: 0.0195 - lr: 0.0010
# Epoch 69/70
# 4/4 [==============================] - 41s 10s/step - loss: 0.0195 - val_loss: 0.0202 - lr: 0.0010
# Epoch 70/70
# 4/4 [==============================] - 44s 11s/step - loss: 0.0200 - val_loss: 0.0213 - lr: 0.0010
# 4/4 [==============================] - 9s 2s/step
# Validation RMSE: 0.14604536806718638

# %%
import matplotlib.pyplot as plt

# Assuming that one_lifeline is your data reshaped correctly for the model input
# Example: one_lifeline = np.random.rand(1, 376, 1)  # Use your actual reshaped data here

# Predict the reconstruction for the lifeline
reconstructed = autoencoder.predict(train_data)
lifeline = 5
feature = 0 

# Flatten the arrays to be able to plot them since they contain a single feature
scaled_series = train_data[lifeline,:,feature]
reconstructed_series = reconstructed[lifeline,:,feature]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(scaled_series, label='Original Data', color='blue')
plt.plot(reconstructed_series, label='Reconstructed Data', color='red', linestyle='--')
plt.title('Lifeline 1 for Single Feature')
plt.xlabel('Timepoint')
plt.ylabel('Value')
plt.legend()
plt.show()
# Out:
# 4/4 [==============================] - 6s 1s/step

# %%
# Create a model that includes the input and the output of the last LSTM layer you consider as the latent space
latent_model = Model(inputs=inputs, outputs=encoded)

# Checking the model summary to ensure it's capturing the correct layer
latent_model.summary()

latent_space_representations = latent_model.predict(train_data)

# latent_space_representations now contains the latent vectors for each timestep
# Calculate the average latent vector across timesteps for each sample
average_latent_vectors = np.mean(latent_space_representations, axis=1)

# Save to CSV using pandas
import pandas as pd

# Convert to DataFrame
df = pd.DataFrame(average_latent_vectors)

# Save DataFrame to CSV
csv_file_path = 'latent_space_representations.csv'
df.to_csv(csv_file_path, index=False)

# %%
lifelines_to_clusters_timesteps = pd.read_csv('lifelines_to_clusters_timesteps.csv')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file with lifeline-cluster pairs
lifelines_to_clusters_timesteps = pd.read_csv('lifelines_to_clusters_timesteps.csv')
lifelines_to_clusters_timesteps.columns = ['lifeline', 'cluster']

# Determine the number of clusters
num_clusters = lifelines_to_clusters_timesteps['cluster'].nunique()

# Setup the figure and axes for a 3x3 grid
fig, axes = plt.subplots(2, 1, figsize=(15, 15))  # Adjust the size as needed
axes = axes.flatten()  # Flatten the 2D array of axes for easy iteration

# Create a plot for each cluster on its own subplot
for cluster_id in range(1, num_clusters + 1):
    # Find all lifelines belonging to the current cluster
    lifelines_in_cluster = lifelines_to_clusters_timesteps[lifelines_to_clusters_timesteps['cluster'] == cluster_id]['lifeline']
    
    # Get the corresponding subplot axis
    ax = axes[cluster_id - 1]
    
    # Plot each lifeline in the cluster
    for lifeline in lifelines_in_cluster:
        # Adjust lifeline index for zero-based indexing
        adjusted_lifeline_index = lifeline - 1
        
        # Extract the lifeline data from train_data
        # Replace 'feature' with the correct index for your feature
        lifeline_data = train_data[adjusted_lifeline_index, :, feature]  
        ax.plot(lifeline_data, label=f'Lifeline {lifeline}')
    
    # Set titles and labels for each subplot
    ax.set_title(f'Cluster {cluster_id}')
    ax.set_xlabel('Time or Sequence')
    ax.set_ylabel('Feature Value')
    ax.legend()

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %%
# Get the weights of the first decoder LSTM layer
decoder_lstm1 = autoencoder.layers[-3]  # Assuming the last three LSTM layers are the decoder
kernel_weights_1, recurrent_weights_1, biases_1 = decoder_lstm1.get_weights()

# Get the weights of the second decoder LSTM layer
decoder_lstm2 = autoencoder.layers[-2]
kernel_weights_2, recurrent_weights_2, biases_2 = decoder_lstm2.get_weights()

# Get the weights of the output layer (TimeDistributed(Dense(...)))
# The TimeDistributed layer wraps the Dense layer, so you need to access the layer attribute
output_layer = autoencoder.layers[-1].layer
output_kernel_weights, output_biases = output_layer.get_weights()


# Function to find the highest absolute weights in a Dense layer
def find_highest_weights_dense(weights, top_n=5):
    # Take the absolute value of the weights
    abs_weights = np.abs(weights)
    # Find the indices of the top 'n' weights
    top_indices = np.unravel_index(np.argsort(abs_weights, axis=None)[-top_n:], weights.shape)
    # Get the top 'n' weights
    top_weights = weights[top_indices]
    return top_indices, top_weights

# Find the top 5 weights in the output dense layer
top_indices, top_weights = find_highest_weights_dense(output_kernel_weights, top_n=5)
print("Top 5 weights indices:", top_indices)
print("Top 5 weights:", top_weights)
# Out:
# Top 5 weights indices: (array([  9, 270, 254, 374,   9], dtype=int64), array([25, 37, 38, 37, 37], dtype=int64))
# Top 5 weights: [-0.3988532  -0.47970894 -0.5011315   0.52769345  0.6915405 ]

# %% [markdown]
# # Time Series Decomposition (Interpretability of Latent Space - Timesteps)

# %%
# Correcting the series extraction from the dataframe or 2D array
# Assuming `df` is a pandas DataFrame or a numpy array with shape (101, 200)

series = df.iloc[0, :].values  # This selects the first lifeline's time series data

# Ensure 'series' is a 1D array suitable for 'seasonal_decompose'
# Note: 'period' should reflect the seasonality in your data; adjust accordingly
result = seasonal_decompose(series, model='additive', period=24)  # Adjust 'period' as needed based on your actual data's seasonality

# Plot the decomposition result
result.plot()
plt.show()
